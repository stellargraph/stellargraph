# %% [markdown]
# # Supervised graph classification with Deep Graph Convolutional Neural Networks
#
# This notebook demonstrates how to train a graph classification model in a supervised setting using the Deep Graph Convolutional Neural Network (DGCNN) [1] algorithm.
#
# In supervised graph classification, we are given a collection of graphs each with an attached categorical label. For example, the PROTEINS dataset we use for this demo is a collection of graphs each representing a chemical compound and labelled as either an enzyme or not. Our goal is to train a machine learning model that uses the graph structure of the data together with any information available for the graph's nodes, e.g., chemical properties for the compounds in PROTEINS, to predict the correct label for a previously unseen graph; a previously unseen graph is one that was not used for training and validating the model.
#
# The DGCNN architecture was proposed in [1] (see Figure 5 in [1]) using the graph convolutional layers from [2] but with a modified propagation rule (see [1] for details). DGCNN introduces a new `SortPooling` layer to generate a representation (also know as embedding) for each given graph using as input the representations learned for each node via a stack of graph convolutional layers. The output of the `SortPooling` layer is then used as input to one-dimensional convolutional, max pooling, and dense layers that learn graph-level features suitable for predicting graph labels.
#
# **References**
#
# [1] An End-to-End Deep Learning Architecture for Graph Classification, M. Zhang, Z. Cui, M. Neumann, Y. Chen, AAAI-18. ([link](https://www.aaai.org/ocs/index.php/AAAI/AAAI18/paper/viewPaper/17146))
#
# [2] Semi-supervised Classification with Graph Convolutional Networks, T. N. Kipf and M. Welling, ICLR 2017. ([link](https://arxiv.org/abs/1609.02907))

# %% [markdown]
# <table><tr><td>Run the master version of this notebook:</td><td><a href="https://mybinder.org/v2/gh/stellargraph/stellargraph/master?urlpath=lab/tree/demos/graph-classification/dgcnn-graph-classification.ipynb" alt="Open In Binder" target="_parent"><img src="https://mybinder.org/badge_logo.svg"/></a></td><td><a href="https://colab.research.google.com/github/stellargraph/stellargraph/blob/master/demos/graph-classification/dgcnn-graph-classification.ipynb" alt="Open In Colab" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg"/></a></td></tr></table>

# %%
# install StellarGraph if running on Google Colab
import sys
if 'google.colab' in sys.modules:
  # %pip install -q stellargraph[demos]

# %%
# verify that we're using the correct version of StellarGraph for this notebook
import stellargraph as sg

try:
    sg.utils.validate_notebook_version("1.0.0b")
except AttributeError:
    raise ValueError(
        f"This notebook requires StellarGraph version 1.0.0b, but a different version {sg.__version__} is installed.  Please see <https://github.com/stellargraph/stellargraph/issues/1172>."
    ) from None

# %%
import pandas as pd
import numpy as np

import stellargraph as sg
from stellargraph.mapper import PaddedGraphGenerator
from stellargraph.layer import DeepGraphConvolutionalNeuralNetwork
from stellargraph import StellarGraph

from stellargraph import datasets

from sklearn import model_selection
from IPython.display import display, HTML

from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Conv1D, MaxPool1D, Dropout
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

# %% [markdown]
# ## Import the data

# %%
dataset = datasets.PROTEINS()
display(HTML(dataset.description))
graphs, graph_labels = dataset.load()
# Out:
# Each graph represents a protein and graph labels represent whether they are are enzymes or non-enzymes. The dataset includes 1113 graphs with 39 nodes and 73 edges on average for each graph. Graph nodes have 4 attributes (including a one-hot encoding of their label), and each graph is labelled as belonging to 1 of 2 classes.

# %%
graph_labels = pd.get_dummies(graph_labels, drop_first=True)

# %% [markdown]
# ### Prepare graph generator
#
# To feed data to the `tf.Keras` model that we will create later, we need a data generator. For supervised graph classification, we create an instance of `StellarGraph`'s `PaddedGraphGenerator` class.

# %%
generator = PaddedGraphGenerator(graphs=graphs)

# %% [markdown]
# ### Create the Keras graph classification model
#
# We are now ready to create a `tf.Keras` graph classification model using `StellarGraph`'s `DeepGraphConvolutionalNeuralNetwork` class together with standard `tf.Keras` layers `Conv1D`, `MapPool1D`, `Dropout`, and `Dense`.
#
# The model's input is the graph represented by its adjacency and node features matrices. The first four layers are Graph Convolutional as in [2] but using the adjacency normalisation from [1], $D^{-1}A$ where $A$ is the adjacency matrix with self loops and $D$ is the corresponding degree matrix. The graph convolutional layers each have 32, 32, 32, 1 units and `tanh` activations.
#
# The next layer is a one dimensional convolutional layer, `Conv1D`, followed by a max pooling, `MaxPool1D`, layer. Next is a second `Conv1D` layer that is followed by two `Dense` layers the second used for binary classification. The convolutional and dense layers use `relu` activation except for the last dense layer that uses `sigmoid` for classification. As described in [1], we add a `Dropout` layer after the first `Dense` layer.

# %% [markdown]
# ![](dgcnn_architecture.png)

# %% [markdown]
# First we create the base DGCNN model that includes the graph convolutional and `SortPooling` layers.

# %%
k = 35  # the number of rows for the output tensor
layer_sizes = [32, 32, 32, 1]

dgcnn_model = DeepGraphConvolutionalNeuralNetwork(
    layer_sizes=layer_sizes,
    activations=["tanh", "tanh", "tanh", "tanh"],
    k=k,
    bias=False,
    generator=generator,
    kernel_regularizer="l2",
    kernel_initializer="glorot_uniform",
)
x_inp, x_out = dgcnn_model.in_out_tensors()

# %% [markdown]
# Next, we add the convolutional, max pooling, and dense layers.

# %%
x_out = Conv1D(filters=16, kernel_size=sum(layer_sizes), strides=sum(layer_sizes))(x_out)
x_out = MaxPool1D(pool_size=2)(x_out)

x_out = Conv1D(filters=32, kernel_size=5, strides=1)(x_out)

x_out = Dense(units=128, activation="relu")(x_out)
x_out = Dropout(rate=0.5)(x_out)

predictions = Dense(units=1, activation="sigmoid")(x_out)

# %% [markdown]
# Finally, we create the `Keras` model and prepare it for training by specifying the loss and optimisation algorithm.

# %%
model = Model(inputs=x_inp, outputs=predictions)

model.compile(
    optimizer=Adam(lr=0.001), loss=binary_crossentropy, metrics=["acc"],
)

# %% [markdown]
# ### Train the model
#
# We can now train the model using the model's `fit` method.
#
# But first we need to split our data to training and test sets. We are going to use 90% of the data for training and the remaining 10% for testing. This 90/10 split is the equivalent of a single fold in the 10-fold cross validation scheme used in [1].

# %%
train_graphs, test_graphs = model_selection.train_test_split(
    graph_labels, train_size=0.9, test_size=None, stratify=graph_labels,
)

# %% [markdown]
# Given the data split into train and test sets, we create a `StellarGraph.PaddedGenerator` generator object that prepares the data for training. We create data generators suitable for training at `tf.keras` model by calling the latter generator's `flow` method specifying the train and test data.

# %%
gen = PaddedGraphGenerator(graphs=graphs)

train_gen = gen.flow(
    list(train_graphs.index - 1),
    targets=train_graphs.values,
    batch_size=50,
    symmetric_normalization=False,
)

test_gen = gen.flow(
    list(test_graphs.index - 1),
    targets=test_graphs.values,
    batch_size=1,
    symmetric_normalization=False,
)

# %%
epochs = 300

# %% [markdown]
# We will use early stopping to prevent overfitting.

# %%
es = EarlyStopping(
    monitor="val_loss", min_delta=0, patience=100, restore_best_weights=True
)

# %% [markdown]
# We can now train the model by calling it's `fit` method.

# %%
history = model.fit(
    train_gen,
    epochs=epochs,
    verbose=1,
    validation_data=test_gen,
    shuffle=True,
    callbacks=[es],
)
# Out:
#   ['...']
#   ['...']
# Train for 21 steps, validate for 112 steps
# Epoch 1/300
# 21/21 [==============================] - 6s 290ms/step - loss: 1.3176 - acc: 0.6613 - val_loss: 1.2227 - val_acc: 0.6951
# Epoch 2/300
# 21/21 [==============================] - 3s 134ms/step - loss: 1.1839 - acc: 0.6823 - val_loss: 1.1045 - val_acc: 0.7067
# Epoch 3/300
# 21/21 [==============================] - 3s 132ms/step - loss: 1.0724 - acc: 0.6848 - val_loss: 1.0166 - val_acc: 0.7047
# Epoch 4/300
# 21/21 [==============================] - 3s 121ms/step - loss: 0.9852 - acc: 0.6854 - val_loss: 0.9306 - val_acc: 0.7060
# Epoch 5/300
# 21/21 [==============================] - 3s 137ms/step - loss: 0.9134 - acc: 0.6848 - val_loss: 0.8643 - val_acc: 0.7115
# Epoch 6/300
# 21/21 [==============================] - 3s 135ms/step - loss: 0.8539 - acc: 0.6878 - val_loss: 0.8116 - val_acc: 0.7115
# Epoch 7/300
# 21/21 [==============================] - 3s 124ms/step - loss: 0.8078 - acc: 0.6882 - val_loss: 0.7723 - val_acc: 0.7067
# Epoch 8/300
# 21/21 [==============================] - 3s 141ms/step - loss: 0.7682 - acc: 0.6857 - val_loss: 0.7359 - val_acc: 0.7122
# Epoch 9/300
# 21/21 [==============================] - 3s 159ms/step - loss: 0.7409 - acc: 0.6881 - val_loss: 0.7122 - val_acc: 0.7095
# Epoch 10/300
# 21/21 [==============================] - 3s 141ms/step - loss: 0.7146 - acc: 0.6879 - val_loss: 0.6855 - val_acc: 0.7143
# Epoch 11/300
# 21/21 [==============================] - 3s 137ms/step - loss: 0.6907 - acc: 0.6875 - val_loss: 0.6668 - val_acc: 0.7102
# Epoch 12/300
# 21/21 [==============================] - 4s 178ms/step - loss: 0.6742 - acc: 0.6881 - val_loss: 0.6558 - val_acc: 0.7109
# Epoch 13/300
# 21/21 [==============================] - 3s 133ms/step - loss: 0.6601 - acc: 0.6882 - val_loss: 0.6406 - val_acc: 0.7102
# Epoch 14/300
# 21/21 [==============================] - 4s 170ms/step - loss: 0.6490 - acc: 0.6871 - val_loss: 0.6295 - val_acc: 0.7150
# Epoch 15/300
# 21/21 [==============================] - 3s 144ms/step - loss: 0.6433 - acc: 0.6883 - val_loss: 0.6218 - val_acc: 0.7122
# Epoch 16/300
# 21/21 [==============================] - 3s 162ms/step - loss: 0.6334 - acc: 0.6925 - val_loss: 0.6189 - val_acc: 0.7122
# Epoch 17/300
# 21/21 [==============================] - 3s 150ms/step - loss: 0.6348 - acc: 0.6922 - val_loss: 0.6120 - val_acc: 0.7129
# Epoch 18/300
# 21/21 [==============================] - 2s 118ms/step - loss: 0.6249 - acc: 0.6905 - val_loss: 0.6131 - val_acc: 0.7129
# Epoch 19/300
# 21/21 [==============================] - 3s 145ms/step - loss: 0.6202 - acc: 0.6905 - val_loss: 0.6092 - val_acc: 0.7150
# Epoch 20/300
# 21/21 [==============================] - 3s 153ms/step - loss: 0.6188 - acc: 0.6899 - val_loss: 0.6024 - val_acc: 0.7109
# Epoch 21/300
# 21/21 [==============================] - 4s 171ms/step - loss: 0.6188 - acc: 0.6948 - val_loss: 0.6046 - val_acc: 0.7143
# Epoch 22/300
# 21/21 [==============================] - 3s 142ms/step - loss: 0.6125 - acc: 0.6938 - val_loss: 0.6006 - val_acc: 0.7205
# Epoch 23/300
# 21/21 [==============================] - 2s 118ms/step - loss: 0.6130 - acc: 0.6877 - val_loss: 0.5958 - val_acc: 0.7191
# Epoch 24/300
# 21/21 [==============================] - 3s 147ms/step - loss: 0.6109 - acc: 0.6919 - val_loss: 0.5950 - val_acc: 0.7184
# Epoch 25/300
# 21/21 [==============================] - 3s 125ms/step - loss: 0.6097 - acc: 0.6935 - val_loss: 0.5951 - val_acc: 0.7218
# Epoch 26/300
# 21/21 [==============================] - 3s 130ms/step - loss: 0.6082 - acc: 0.6945 - val_loss: 0.6172 - val_acc: 0.7102
# Epoch 27/300
# 21/21 [==============================] - 3s 140ms/step - loss: 0.6153 - acc: 0.6880 - val_loss: 0.5946 - val_acc: 0.7143
# Epoch 28/300
# 21/21 [==============================] - 3s 129ms/step - loss: 0.6044 - acc: 0.6981 - val_loss: 0.6070 - val_acc: 0.7136
# Epoch 29/300
# 21/21 [==============================] - 3s 134ms/step - loss: 0.6104 - acc: 0.6933 - val_loss: 0.5951 - val_acc: 0.7129
# Epoch 30/300
# 21/21 [==============================] - 3s 147ms/step - loss: 0.6041 - acc: 0.6905 - val_loss: 0.5961 - val_acc: 0.7170
# Epoch 31/300
# 21/21 [==============================] - 2s 118ms/step - loss: 0.6022 - acc: 0.6953 - val_loss: 0.5963 - val_acc: 0.7184
# Epoch 32/300
# 21/21 [==============================] - 3s 145ms/step - loss: 0.5980 - acc: 0.6963 - val_loss: 0.5882 - val_acc: 0.7212
# Epoch 33/300
# 21/21 [==============================] - 3s 131ms/step - loss: 0.5994 - acc: 0.7005 - val_loss: 0.6378 - val_acc: 0.6889
# Epoch 34/300
# 21/21 [==============================] - 3s 144ms/step - loss: 0.6198 - acc: 0.6875 - val_loss: 0.6045 - val_acc: 0.7150
# Epoch 35/300
# 21/21 [==============================] - 3s 157ms/step - loss: 0.6015 - acc: 0.6924 - val_loss: 0.5896 - val_acc: 0.7150
# Epoch 36/300
# 21/21 [==============================] - 3s 125ms/step - loss: 0.6002 - acc: 0.6988 - val_loss: 0.5938 - val_acc: 0.7122
# Epoch 37/300
# 21/21 [==============================] - 3s 163ms/step - loss: 0.6048 - acc: 0.6944 - val_loss: 0.6145 - val_acc: 0.7129
# Epoch 38/300
# 21/21 [==============================] - 3s 140ms/step - loss: 0.5965 - acc: 0.6948 - val_loss: 0.6016 - val_acc: 0.7136
# Epoch 39/300
# 21/21 [==============================] - 3s 148ms/step - loss: 0.6010 - acc: 0.6927 - val_loss: 0.5879 - val_acc: 0.7074
# Epoch 40/300
# 21/21 [==============================] - 3s 166ms/step - loss: 0.5978 - acc: 0.6952 - val_loss: 0.5952 - val_acc: 0.7212
# Epoch 41/300
# 21/21 [==============================] - 3s 158ms/step - loss: 0.5976 - acc: 0.6925 - val_loss: 0.5856 - val_acc: 0.7191
# Epoch 42/300
# 21/21 [==============================] - 3s 150ms/step - loss: 0.5895 - acc: 0.6943 - val_loss: 0.5984 - val_acc: 0.7095
# Epoch 43/300
# 21/21 [==============================] - 4s 187ms/step - loss: 0.5892 - acc: 0.6979 - val_loss: 0.5887 - val_acc: 0.7095
# Epoch 44/300
# 21/21 [==============================] - 3s 130ms/step - loss: 0.5862 - acc: 0.6998 - val_loss: 0.6001 - val_acc: 0.7157
# Epoch 45/300
# 21/21 [==============================] - 4s 178ms/step - loss: 0.5936 - acc: 0.6940 - val_loss: 0.5983 - val_acc: 0.7150
# Epoch 46/300
# 21/21 [==============================] - 3s 151ms/step - loss: 0.5885 - acc: 0.7018 - val_loss: 0.5974 - val_acc: 0.7163
# Epoch 47/300
# 21/21 [==============================] - 3s 138ms/step - loss: 0.5936 - acc: 0.6961 - val_loss: 0.6012 - val_acc: 0.6806
# Epoch 48/300
# 21/21 [==============================] - 4s 171ms/step - loss: 0.5930 - acc: 0.7046 - val_loss: 0.6046 - val_acc: 0.7019
# Epoch 49/300
# 21/21 [==============================] - 3s 132ms/step - loss: 0.5922 - acc: 0.6968 - val_loss: 0.5918 - val_acc: 0.7095
# Epoch 50/300
# 21/21 [==============================] - 3s 134ms/step - loss: 0.5918 - acc: 0.6954 - val_loss: 0.5996 - val_acc: 0.7012
# Epoch 51/300
# 21/21 [==============================] - 3s 151ms/step - loss: 0.5896 - acc: 0.6955 - val_loss: 0.6017 - val_acc: 0.7170
# Epoch 52/300
# 21/21 [==============================] - 3s 132ms/step - loss: 0.5931 - acc: 0.6956 - val_loss: 0.5877 - val_acc: 0.6999
# Epoch 53/300
# 21/21 [==============================] - 3s 143ms/step - loss: 0.5867 - acc: 0.7012 - val_loss: 0.5981 - val_acc: 0.7198
# Epoch 54/300
# 21/21 [==============================] - 3s 147ms/step - loss: 0.5868 - acc: 0.7005 - val_loss: 0.6002 - val_acc: 0.7040
# Epoch 55/300
# 21/21 [==============================] - 3s 134ms/step - loss: 0.5866 - acc: 0.7031 - val_loss: 0.5905 - val_acc: 0.7060
# Epoch 56/300
# 21/21 [==============================] - 3s 149ms/step - loss: 0.5847 - acc: 0.7038 - val_loss: 0.5988 - val_acc: 0.7074
# Epoch 57/300
# 21/21 [==============================] - 3s 160ms/step - loss: 0.5840 - acc: 0.6988 - val_loss: 0.5875 - val_acc: 0.6978
# Epoch 58/300
# 21/21 [==============================] - 3s 128ms/step - loss: 0.5893 - acc: 0.6927 - val_loss: 0.5877 - val_acc: 0.6951
# Epoch 59/300
# 21/21 [==============================] - 3s 139ms/step - loss: 0.5958 - acc: 0.6950 - val_loss: 0.5845 - val_acc: 0.7102
# Epoch 60/300
# 21/21 [==============================] - 3s 129ms/step - loss: 0.5908 - acc: 0.6947 - val_loss: 0.5922 - val_acc: 0.7005
# Epoch 61/300
# 21/21 [==============================] - 3s 121ms/step - loss: 0.5962 - acc: 0.6930 - val_loss: 0.6047 - val_acc: 0.7067
# Epoch 62/300
# 21/21 [==============================] - 3s 136ms/step - loss: 0.6008 - acc: 0.6935 - val_loss: 0.5882 - val_acc: 0.7143
# Epoch 63/300
# 21/21 [==============================] - 3s 121ms/step - loss: 0.5925 - acc: 0.6969 - val_loss: 0.5858 - val_acc: 0.7163
# Epoch 64/300
# 21/21 [==============================] - 3s 154ms/step - loss: 0.5984 - acc: 0.6921 - val_loss: 0.5930 - val_acc: 0.7095
# Epoch 65/300
# 21/21 [==============================] - 3s 119ms/step - loss: 0.5878 - acc: 0.6958 - val_loss: 0.5913 - val_acc: 0.7212
# Epoch 66/300
# 21/21 [==============================] - 3s 124ms/step - loss: 0.5900 - acc: 0.6982 - val_loss: 0.5880 - val_acc: 0.7019
# Epoch 67/300
# 21/21 [==============================] - 3s 134ms/step - loss: 0.5920 - acc: 0.6905 - val_loss: 0.6012 - val_acc: 0.7088
# Epoch 68/300
# 21/21 [==============================] - 3s 135ms/step - loss: 0.5938 - acc: 0.6949 - val_loss: 0.6219 - val_acc: 0.6806
# Epoch 69/300
# 21/21 [==============================] - 3s 123ms/step - loss: 0.5946 - acc: 0.7009 - val_loss: 0.5884 - val_acc: 0.7074
# Epoch 70/300
# 21/21 [==============================] - 3s 142ms/step - loss: 0.5943 - acc: 0.6961 - val_loss: 0.5915 - val_acc: 0.7170
# Epoch 71/300
# 21/21 [==============================] - 2s 118ms/step - loss: 0.5882 - acc: 0.7004 - val_loss: 0.5837 - val_acc: 0.7170
# Epoch 72/300
# 21/21 [==============================] - 3s 154ms/step - loss: 0.5868 - acc: 0.6987 - val_loss: 0.5845 - val_acc: 0.7088
# Epoch 73/300
# 21/21 [==============================] - 3s 128ms/step - loss: 0.5969 - acc: 0.6934 - val_loss: 0.5848 - val_acc: 0.7143
# Epoch 74/300
# 21/21 [==============================] - 3s 131ms/step - loss: 0.5916 - acc: 0.6984 - val_loss: 0.5924 - val_acc: 0.7301
# Epoch 75/300
# 21/21 [==============================] - 3s 134ms/step - loss: 0.5966 - acc: 0.6971 - val_loss: 0.5992 - val_acc: 0.7225
# Epoch 76/300
# 21/21 [==============================] - 3s 121ms/step - loss: 0.5885 - acc: 0.7014 - val_loss: 0.5880 - val_acc: 0.7170
# Epoch 77/300
# 21/21 [==============================] - 3s 131ms/step - loss: 0.5890 - acc: 0.6999 - val_loss: 0.5845 - val_acc: 0.7163
# Epoch 78/300
# 21/21 [==============================] - 3s 126ms/step - loss: 0.5881 - acc: 0.7004 - val_loss: 0.5854 - val_acc: 0.7150
# Epoch 79/300
# 21/21 [==============================] - 2s 118ms/step - loss: 0.5885 - acc: 0.6998 - val_loss: 0.5901 - val_acc: 0.7019
# Epoch 80/300
# 21/21 [==============================] - 3s 136ms/step - loss: 0.5892 - acc: 0.6967 - val_loss: 0.5989 - val_acc: 0.6971
# Epoch 81/300
# 21/21 [==============================] - 3s 130ms/step - loss: 0.5847 - acc: 0.6974 - val_loss: 0.5896 - val_acc: 0.7047
# Epoch 82/300
# 21/21 [==============================] - 3s 131ms/step - loss: 0.5822 - acc: 0.7017 - val_loss: 0.5929 - val_acc: 0.7019
# Epoch 83/300
# 21/21 [==============================] - 3s 127ms/step - loss: 0.5876 - acc: 0.6983 - val_loss: 0.5854 - val_acc: 0.7040
# Epoch 84/300
# 21/21 [==============================] - 3s 128ms/step - loss: 0.5871 - acc: 0.6965 - val_loss: 0.5865 - val_acc: 0.7170
# Epoch 85/300
# 21/21 [==============================] - 3s 133ms/step - loss: 0.5805 - acc: 0.7054 - val_loss: 0.5893 - val_acc: 0.6957
# Epoch 86/300
# 21/21 [==============================] - 3s 151ms/step - loss: 0.5806 - acc: 0.7033 - val_loss: 0.5872 - val_acc: 0.7102
# Epoch 87/300
# 21/21 [==============================] - 3s 129ms/step - loss: 0.5796 - acc: 0.7044 - val_loss: 0.5884 - val_acc: 0.7005
# Epoch 88/300
# 21/21 [==============================] - 3s 125ms/step - loss: 0.5838 - acc: 0.7007 - val_loss: 0.5904 - val_acc: 0.6971
# Epoch 89/300
# 21/21 [==============================] - 3s 135ms/step - loss: 0.5867 - acc: 0.6997 - val_loss: 0.5906 - val_acc: 0.7088
# Epoch 90/300
# 21/21 [==============================] - 3s 126ms/step - loss: 0.5866 - acc: 0.6935 - val_loss: 0.5862 - val_acc: 0.7026
# Epoch 91/300
# 21/21 [==============================] - 3s 141ms/step - loss: 0.5935 - acc: 0.6977 - val_loss: 0.5954 - val_acc: 0.7109
# Epoch 92/300
# 21/21 [==============================] - 2s 117ms/step - loss: 0.5884 - acc: 0.6974 - val_loss: 0.5871 - val_acc: 0.7115
# Epoch 93/300
# 21/21 [==============================] - 3s 150ms/step - loss: 0.5866 - acc: 0.6979 - val_loss: 0.5942 - val_acc: 0.6978
# Epoch 94/300
# 21/21 [==============================] - 3s 140ms/step - loss: 0.5884 - acc: 0.6950 - val_loss: 0.5872 - val_acc: 0.7005
# Epoch 95/300
# 21/21 [==============================] - 3s 120ms/step - loss: 0.5889 - acc: 0.6956 - val_loss: 0.5863 - val_acc: 0.7184
# Epoch 96/300
# 21/21 [==============================] - 3s 130ms/step - loss: 0.5875 - acc: 0.6995 - val_loss: 0.5993 - val_acc: 0.7205
# Epoch 97/300
# 21/21 [==============================] - 3s 124ms/step - loss: 0.5866 - acc: 0.6968 - val_loss: 0.5838 - val_acc: 0.7115
# Epoch 98/300
# 21/21 [==============================] - 3s 138ms/step - loss: 0.5848 - acc: 0.7025 - val_loss: 0.5903 - val_acc: 0.7163
# Epoch 99/300
# 21/21 [==============================] - 3s 146ms/step - loss: 0.5853 - acc: 0.6992 - val_loss: 0.5859 - val_acc: 0.7005
# Epoch 100/300
# 21/21 [==============================] - 3s 124ms/step - loss: 0.5849 - acc: 0.6991 - val_loss: 0.5897 - val_acc: 0.7109
# Epoch 101/300
# 21/21 [==============================] - 3s 130ms/step - loss: 0.5903 - acc: 0.6963 - val_loss: 0.5849 - val_acc: 0.7095
# Epoch 102/300
# 21/21 [==============================] - 3s 138ms/step - loss: 0.5849 - acc: 0.7031 - val_loss: 0.5853 - val_acc: 0.7074
# Epoch 103/300
# 21/21 [==============================] - 3s 133ms/step - loss: 0.5884 - acc: 0.6949 - val_loss: 0.5865 - val_acc: 0.7102
# Epoch 104/300
# 21/21 [==============================] - 3s 139ms/step - loss: 0.5831 - acc: 0.7006 - val_loss: 0.5916 - val_acc: 0.7054
# Epoch 105/300
# 21/21 [==============================] - 3s 129ms/step - loss: 0.5801 - acc: 0.7035 - val_loss: 0.5899 - val_acc: 0.6889
# Epoch 106/300
# 21/21 [==============================] - 3s 142ms/step - loss: 0.5796 - acc: 0.7034 - val_loss: 0.5859 - val_acc: 0.7033
# Epoch 107/300
# 21/21 [==============================] - 3s 157ms/step - loss: 0.5798 - acc: 0.7021 - val_loss: 0.5979 - val_acc: 0.7095
# Epoch 108/300
# 21/21 [==============================] - 3s 126ms/step - loss: 0.5866 - acc: 0.6997 - val_loss: 0.5892 - val_acc: 0.6985
# Epoch 109/300
# 21/21 [==============================] - 3s 144ms/step - loss: 0.5876 - acc: 0.6953 - val_loss: 0.5831 - val_acc: 0.7019
# Epoch 110/300
# 21/21 [==============================] - 3s 126ms/step - loss: 0.5843 - acc: 0.7028 - val_loss: 0.5858 - val_acc: 0.7102
# Epoch 111/300
# 21/21 [==============================] - 3s 146ms/step - loss: 0.5888 - acc: 0.6975 - val_loss: 0.5905 - val_acc: 0.7095
# Epoch 112/300
# 21/21 [==============================] - 3s 131ms/step - loss: 0.5871 - acc: 0.6999 - val_loss: 0.5861 - val_acc: 0.6992
# Epoch 113/300
# 21/21 [==============================] - 2s 118ms/step - loss: 0.5807 - acc: 0.7052 - val_loss: 0.5870 - val_acc: 0.7019
# Epoch 114/300
# 21/21 [==============================] - 3s 134ms/step - loss: 0.5786 - acc: 0.7070 - val_loss: 0.6063 - val_acc: 0.6841
# Epoch 115/300
# 21/21 [==============================] - 3s 131ms/step - loss: 0.5919 - acc: 0.6929 - val_loss: 0.5887 - val_acc: 0.7191
# Epoch 116/300
# 21/21 [==============================] - 3s 130ms/step - loss: 0.5834 - acc: 0.6981 - val_loss: 0.5849 - val_acc: 0.6999
# Epoch 117/300
# 21/21 [==============================] - 3s 125ms/step - loss: 0.5888 - acc: 0.6975 - val_loss: 0.5798 - val_acc: 0.7253
# Epoch 118/300
# 21/21 [==============================] - 3s 128ms/step - loss: 0.5843 - acc: 0.7031 - val_loss: 0.5890 - val_acc: 0.7212
# Epoch 119/300
# 21/21 [==============================] - 3s 135ms/step - loss: 0.5856 - acc: 0.7000 - val_loss: 0.5859 - val_acc: 0.7163
# Epoch 120/300
# 21/21 [==============================] - 3s 132ms/step - loss: 0.5824 - acc: 0.6981 - val_loss: 0.5891 - val_acc: 0.6957
# Epoch 121/300
# 21/21 [==============================] - 2s 116ms/step - loss: 0.5820 - acc: 0.6986 - val_loss: 0.5893 - val_acc: 0.7074
# Epoch 122/300
# 21/21 [==============================] - 3s 140ms/step - loss: 0.5854 - acc: 0.7003 - val_loss: 0.5886 - val_acc: 0.7184
# Epoch 123/300
# 21/21 [==============================] - 3s 135ms/step - loss: 0.5825 - acc: 0.7070 - val_loss: 0.5796 - val_acc: 0.7150
# Epoch 124/300
# 21/21 [==============================] - 3s 143ms/step - loss: 0.5897 - acc: 0.6955 - val_loss: 0.5950 - val_acc: 0.7060
# Epoch 125/300
# 21/21 [==============================] - 3s 128ms/step - loss: 0.5816 - acc: 0.6998 - val_loss: 0.5865 - val_acc: 0.7081
# Epoch 126/300
# 21/21 [==============================] - 3s 149ms/step - loss: 0.5828 - acc: 0.7030 - val_loss: 0.6126 - val_acc: 0.6793
# Epoch 127/300
# 21/21 [==============================] - 3s 131ms/step - loss: 0.5801 - acc: 0.7032 - val_loss: 0.5887 - val_acc: 0.6978
# Epoch 128/300
# 21/21 [==============================] - 3s 138ms/step - loss: 0.5814 - acc: 0.7022 - val_loss: 0.6115 - val_acc: 0.6834
# Epoch 129/300
# 21/21 [==============================] - 2s 114ms/step - loss: 0.5817 - acc: 0.7005 - val_loss: 0.5912 - val_acc: 0.7157
# Epoch 130/300
# 21/21 [==============================] - 3s 133ms/step - loss: 0.5879 - acc: 0.6943 - val_loss: 0.5849 - val_acc: 0.7109
# Epoch 131/300
# 21/21 [==============================] - 2s 118ms/step - loss: 0.5790 - acc: 0.7028 - val_loss: 0.5850 - val_acc: 0.7095
# Epoch 132/300
# 21/21 [==============================] - 3s 124ms/step - loss: 0.5769 - acc: 0.7019 - val_loss: 0.5917 - val_acc: 0.6951
# Epoch 133/300
# 21/21 [==============================] - 3s 139ms/step - loss: 0.5884 - acc: 0.7001 - val_loss: 0.5846 - val_acc: 0.7026
# Epoch 134/300
# 21/21 [==============================] - 3s 127ms/step - loss: 0.5839 - acc: 0.7048 - val_loss: 0.5823 - val_acc: 0.7088
# Epoch 135/300
# 21/21 [==============================] - 3s 142ms/step - loss: 0.5782 - acc: 0.7035 - val_loss: 0.5943 - val_acc: 0.7088
# Epoch 136/300
# 21/21 [==============================] - 2s 115ms/step - loss: 0.5864 - acc: 0.6970 - val_loss: 0.5896 - val_acc: 0.7136
# Epoch 137/300
# 21/21 [==============================] - 3s 128ms/step - loss: 0.5846 - acc: 0.7020 - val_loss: 0.5907 - val_acc: 0.7122
# Epoch 138/300
# 21/21 [==============================] - 3s 137ms/step - loss: 0.5842 - acc: 0.6999 - val_loss: 0.5896 - val_acc: 0.7184
# Epoch 139/300
# 21/21 [==============================] - 2s 113ms/step - loss: 0.5783 - acc: 0.7051 - val_loss: 0.5905 - val_acc: 0.6875
# Epoch 140/300
# 21/21 [==============================] - 3s 138ms/step - loss: 0.5844 - acc: 0.7008 - val_loss: 0.5974 - val_acc: 0.7088
# Epoch 141/300
# 21/21 [==============================] - 3s 128ms/step - loss: 0.5886 - acc: 0.6982 - val_loss: 0.5801 - val_acc: 0.7129
# Epoch 142/300
# 21/21 [==============================] - 3s 123ms/step - loss: 0.5858 - acc: 0.6989 - val_loss: 0.5878 - val_acc: 0.7054
# Epoch 143/300
# 21/21 [==============================] - 3s 135ms/step - loss: 0.5868 - acc: 0.7001 - val_loss: 0.5929 - val_acc: 0.6964
# Epoch 144/300
# 21/21 [==============================] - 2s 111ms/step - loss: 0.5835 - acc: 0.6973 - val_loss: 0.5920 - val_acc: 0.7184
# Epoch 145/300
# 21/21 [==============================] - 3s 152ms/step - loss: 0.5794 - acc: 0.7065 - val_loss: 0.5794 - val_acc: 0.7067
# Epoch 146/300
# 21/21 [==============================] - 2s 118ms/step - loss: 0.5809 - acc: 0.6995 - val_loss: 0.5958 - val_acc: 0.7081
# Epoch 147/300
# 21/21 [==============================] - 3s 120ms/step - loss: 0.5882 - acc: 0.7037 - val_loss: 0.5885 - val_acc: 0.6999
# Epoch 148/300
# 21/21 [==============================] - 3s 130ms/step - loss: 0.5850 - acc: 0.6993 - val_loss: 0.5836 - val_acc: 0.7026
# Epoch 149/300
# 21/21 [==============================] - 2s 115ms/step - loss: 0.5834 - acc: 0.6988 - val_loss: 0.5859 - val_acc: 0.7191
# Epoch 150/300
# 21/21 [==============================] - 3s 152ms/step - loss: 0.5781 - acc: 0.7067 - val_loss: 0.5816 - val_acc: 0.7095
# Epoch 151/300
# 21/21 [==============================] - 3s 135ms/step - loss: 0.5816 - acc: 0.7025 - val_loss: 0.5880 - val_acc: 0.6999
# Epoch 152/300
# 21/21 [==============================] - 2s 117ms/step - loss: 0.5840 - acc: 0.7025 - val_loss: 0.5857 - val_acc: 0.7115
# Epoch 153/300
# 21/21 [==============================] - 3s 129ms/step - loss: 0.5772 - acc: 0.7005 - val_loss: 0.5905 - val_acc: 0.7143
# Epoch 154/300
# 21/21 [==============================] - 2s 116ms/step - loss: 0.5809 - acc: 0.7021 - val_loss: 0.5832 - val_acc: 0.7074
# Epoch 155/300
# 21/21 [==============================] - 3s 120ms/step - loss: 0.5842 - acc: 0.6998 - val_loss: 0.5875 - val_acc: 0.6978
# Epoch 156/300
# 21/21 [==============================] - 3s 123ms/step - loss: 0.5792 - acc: 0.7061 - val_loss: 0.5917 - val_acc: 0.7218
# Epoch 157/300
# 21/21 [==============================] - 2s 109ms/step - loss: 0.5793 - acc: 0.6991 - val_loss: 0.5884 - val_acc: 0.7150
# Epoch 158/300
# 21/21 [==============================] - 2s 90ms/step - loss: 0.5817 - acc: 0.7025 - val_loss: 0.5875 - val_acc: 0.7012
# Epoch 159/300
# 21/21 [==============================] - 2s 81ms/step - loss: 0.5790 - acc: 0.7045 - val_loss: 0.5858 - val_acc: 0.7067
# Epoch 160/300
# 21/21 [==============================] - 2s 80ms/step - loss: 0.5813 - acc: 0.7018 - val_loss: 0.5874 - val_acc: 0.7088
# Epoch 161/300
# 21/21 [==============================] - 2s 81ms/step - loss: 0.5789 - acc: 0.7037 - val_loss: 0.6174 - val_acc: 0.6683
# Epoch 162/300
# 21/21 [==============================] - 2s 81ms/step - loss: 0.5895 - acc: 0.6988 - val_loss: 0.6092 - val_acc: 0.7005
# Epoch 163/300
# 21/21 [==============================] - 2s 81ms/step - loss: 0.5871 - acc: 0.7008 - val_loss: 0.5849 - val_acc: 0.7163
# Epoch 164/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5895 - acc: 0.6940 - val_loss: 0.5997 - val_acc: 0.7012
# Epoch 165/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5797 - acc: 0.7054 - val_loss: 0.5840 - val_acc: 0.7074
# Epoch 166/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5813 - acc: 0.6981 - val_loss: 0.5899 - val_acc: 0.7005
# Epoch 167/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5851 - acc: 0.6995 - val_loss: 0.5899 - val_acc: 0.7184
# Epoch 168/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5849 - acc: 0.6995 - val_loss: 0.5853 - val_acc: 0.7109
# Epoch 169/300
# 21/21 [==============================] - 2s 86ms/step - loss: 0.5757 - acc: 0.7044 - val_loss: 0.5867 - val_acc: 0.7143
# Epoch 170/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5830 - acc: 0.7001 - val_loss: 0.5823 - val_acc: 0.7253
# Epoch 171/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5814 - acc: 0.6993 - val_loss: 0.6009 - val_acc: 0.7033
# Epoch 172/300
# 21/21 [==============================] - 2s 82ms/step - loss: 0.5830 - acc: 0.6976 - val_loss: 0.5927 - val_acc: 0.7129
# Epoch 173/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5841 - acc: 0.6992 - val_loss: 0.5884 - val_acc: 0.7095
# Epoch 174/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5850 - acc: 0.6973 - val_loss: 0.5869 - val_acc: 0.7177
# Epoch 175/300
# 21/21 [==============================] - 2s 81ms/step - loss: 0.5806 - acc: 0.6990 - val_loss: 0.5958 - val_acc: 0.6944
# Epoch 176/300
# 21/21 [==============================] - 2s 82ms/step - loss: 0.5835 - acc: 0.6971 - val_loss: 0.5846 - val_acc: 0.7205
# Epoch 177/300
# 21/21 [==============================] - 2s 87ms/step - loss: 0.5806 - acc: 0.7041 - val_loss: 0.5924 - val_acc: 0.7218
# Epoch 178/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5851 - acc: 0.6962 - val_loss: 0.5877 - val_acc: 0.7115
# Epoch 179/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5835 - acc: 0.6998 - val_loss: 0.5842 - val_acc: 0.7102
# Epoch 180/300
# 21/21 [==============================] - 2s 90ms/step - loss: 0.5761 - acc: 0.7091 - val_loss: 0.5872 - val_acc: 0.7067
# Epoch 181/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5791 - acc: 0.7055 - val_loss: 0.5918 - val_acc: 0.7143
# Epoch 182/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5933 - acc: 0.6971 - val_loss: 0.6076 - val_acc: 0.7005
# Epoch 183/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5924 - acc: 0.7005 - val_loss: 0.5922 - val_acc: 0.6964
# Epoch 184/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5919 - acc: 0.6893 - val_loss: 0.5890 - val_acc: 0.7177
# Epoch 185/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5786 - acc: 0.7061 - val_loss: 0.5791 - val_acc: 0.6978
# Epoch 186/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5859 - acc: 0.6980 - val_loss: 0.5886 - val_acc: 0.7067
# Epoch 187/300
# 21/21 [==============================] - 2s 82ms/step - loss: 0.5783 - acc: 0.7046 - val_loss: 0.5959 - val_acc: 0.7019
# Epoch 188/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5816 - acc: 0.6988 - val_loss: 0.6176 - val_acc: 0.6820
# Epoch 189/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5883 - acc: 0.6975 - val_loss: 0.5812 - val_acc: 0.7122
# Epoch 190/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5831 - acc: 0.6994 - val_loss: 0.5784 - val_acc: 0.7212
# Epoch 191/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5837 - acc: 0.7010 - val_loss: 0.5804 - val_acc: 0.7033
# Epoch 192/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5829 - acc: 0.7016 - val_loss: 0.5832 - val_acc: 0.7177
# Epoch 193/300
# 21/21 [==============================] - 2s 81ms/step - loss: 0.5819 - acc: 0.6986 - val_loss: 0.5865 - val_acc: 0.7088
# Epoch 194/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5866 - acc: 0.7011 - val_loss: 0.5841 - val_acc: 0.7102
# Epoch 195/300
# 21/21 [==============================] - 2s 81ms/step - loss: 0.5782 - acc: 0.7038 - val_loss: 0.5738 - val_acc: 0.7157
# Epoch 196/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5790 - acc: 0.7051 - val_loss: 0.5803 - val_acc: 0.7033
# Epoch 197/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5765 - acc: 0.7017 - val_loss: 0.5852 - val_acc: 0.7033
# Epoch 198/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5763 - acc: 0.7065 - val_loss: 0.5830 - val_acc: 0.6985
# Epoch 199/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5735 - acc: 0.7054 - val_loss: 0.5871 - val_acc: 0.7095
# Epoch 200/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5804 - acc: 0.6996 - val_loss: 0.5845 - val_acc: 0.7191
# Epoch 201/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5809 - acc: 0.7010 - val_loss: 0.5889 - val_acc: 0.7019
# Epoch 202/300
# 21/21 [==============================] - 2s 81ms/step - loss: 0.5726 - acc: 0.7058 - val_loss: 0.5954 - val_acc: 0.7157
# Epoch 203/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5793 - acc: 0.7020 - val_loss: 0.5996 - val_acc: 0.6889
# Epoch 204/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5811 - acc: 0.7012 - val_loss: 0.5910 - val_acc: 0.6999
# Epoch 205/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5782 - acc: 0.6998 - val_loss: 0.5879 - val_acc: 0.7163
# Epoch 206/300
# 21/21 [==============================] - 2s 82ms/step - loss: 0.5835 - acc: 0.7005 - val_loss: 0.5901 - val_acc: 0.7143
# Epoch 207/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5866 - acc: 0.6993 - val_loss: 0.5775 - val_acc: 0.7012
# Epoch 208/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5834 - acc: 0.6944 - val_loss: 0.5827 - val_acc: 0.7129
# Epoch 209/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5791 - acc: 0.7030 - val_loss: 0.5816 - val_acc: 0.7019
# Epoch 210/300
# 21/21 [==============================] - 2s 82ms/step - loss: 0.5769 - acc: 0.7020 - val_loss: 0.5808 - val_acc: 0.7019
# Epoch 211/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5806 - acc: 0.7015 - val_loss: 0.5887 - val_acc: 0.7143
# Epoch 212/300
# 21/21 [==============================] - 2s 82ms/step - loss: 0.5860 - acc: 0.7041 - val_loss: 0.6017 - val_acc: 0.7026
# Epoch 213/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5819 - acc: 0.6982 - val_loss: 0.5923 - val_acc: 0.7054
# Epoch 214/300
# 21/21 [==============================] - 2s 86ms/step - loss: 0.5818 - acc: 0.6958 - val_loss: 0.5839 - val_acc: 0.7074
# Epoch 215/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5793 - acc: 0.7052 - val_loss: 0.5743 - val_acc: 0.7102
# Epoch 216/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5895 - acc: 0.6960 - val_loss: 0.5856 - val_acc: 0.7109
# Epoch 217/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5837 - acc: 0.6995 - val_loss: 0.5938 - val_acc: 0.7150
# Epoch 218/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5770 - acc: 0.7085 - val_loss: 0.5918 - val_acc: 0.7102
# Epoch 219/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5751 - acc: 0.7061 - val_loss: 0.5989 - val_acc: 0.6951
# Epoch 220/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5810 - acc: 0.6995 - val_loss: 0.5843 - val_acc: 0.7095
# Epoch 221/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5812 - acc: 0.7034 - val_loss: 0.5819 - val_acc: 0.7143
# Epoch 222/300
# 21/21 [==============================] - 2s 90ms/step - loss: 0.5810 - acc: 0.7029 - val_loss: 0.5799 - val_acc: 0.7177
# Epoch 223/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5835 - acc: 0.6980 - val_loss: 0.5974 - val_acc: 0.6971
# Epoch 224/300
# 21/21 [==============================] - 2s 95ms/step - loss: 0.5837 - acc: 0.7000 - val_loss: 0.5870 - val_acc: 0.7081
# Epoch 225/300
# 21/21 [==============================] - 2s 98ms/step - loss: 0.5856 - acc: 0.6998 - val_loss: 0.5863 - val_acc: 0.7115
# Epoch 226/300
# 21/21 [==============================] - 2s 86ms/step - loss: 0.5792 - acc: 0.7011 - val_loss: 0.5843 - val_acc: 0.7060
# Epoch 227/300
# 21/21 [==============================] - 2s 96ms/step - loss: 0.5773 - acc: 0.7076 - val_loss: 0.5977 - val_acc: 0.7033
# Epoch 228/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5862 - acc: 0.7012 - val_loss: 0.6105 - val_acc: 0.6793
# Epoch 229/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5726 - acc: 0.7088 - val_loss: 0.5849 - val_acc: 0.7157
# Epoch 230/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5749 - acc: 0.7078 - val_loss: 0.5894 - val_acc: 0.7054
# Epoch 231/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5805 - acc: 0.7035 - val_loss: 0.5868 - val_acc: 0.6957
# Epoch 232/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5739 - acc: 0.7056 - val_loss: 0.5795 - val_acc: 0.7170
# Epoch 233/300
# 21/21 [==============================] - 2s 98ms/step - loss: 0.5775 - acc: 0.7055 - val_loss: 0.5942 - val_acc: 0.7143
# Epoch 234/300
# 21/21 [==============================] - 2s 105ms/step - loss: 0.5774 - acc: 0.6995 - val_loss: 0.5834 - val_acc: 0.7150
# Epoch 235/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5807 - acc: 0.7070 - val_loss: 0.5931 - val_acc: 0.7143
# Epoch 236/300
# 21/21 [==============================] - 2s 95ms/step - loss: 0.5778 - acc: 0.7041 - val_loss: 0.5868 - val_acc: 0.6964
# Epoch 237/300
# 21/21 [==============================] - 2s 92ms/step - loss: 0.5807 - acc: 0.7049 - val_loss: 0.5760 - val_acc: 0.7067
# Epoch 238/300
# 21/21 [==============================] - 2s 97ms/step - loss: 0.5752 - acc: 0.7056 - val_loss: 0.5849 - val_acc: 0.7157
# Epoch 239/300
# 21/21 [==============================] - 2s 99ms/step - loss: 0.5795 - acc: 0.6994 - val_loss: 0.5747 - val_acc: 0.7260
# Epoch 240/300
# 21/21 [==============================] - 2s 93ms/step - loss: 0.5755 - acc: 0.7031 - val_loss: 0.5790 - val_acc: 0.7191
# Epoch 241/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5697 - acc: 0.7066 - val_loss: 0.6139 - val_acc: 0.6724
# Epoch 242/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5821 - acc: 0.7036 - val_loss: 0.5814 - val_acc: 0.7143
# Epoch 243/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5771 - acc: 0.7054 - val_loss: 0.5841 - val_acc: 0.7074
# Epoch 244/300
# 21/21 [==============================] - 2s 87ms/step - loss: 0.5719 - acc: 0.7073 - val_loss: 0.5823 - val_acc: 0.7102
# Epoch 245/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5941 - acc: 0.6922 - val_loss: 0.5895 - val_acc: 0.7184
# Epoch 246/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5851 - acc: 0.7032 - val_loss: 0.5983 - val_acc: 0.7177
# Epoch 247/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5808 - acc: 0.7043 - val_loss: 0.5791 - val_acc: 0.7095
# Epoch 248/300
# 21/21 [==============================] - 2s 82ms/step - loss: 0.5797 - acc: 0.7048 - val_loss: 0.5772 - val_acc: 0.7095
# Epoch 249/300
# 21/21 [==============================] - 2s 83ms/step - loss: 0.5836 - acc: 0.7021 - val_loss: 0.5926 - val_acc: 0.7047
# Epoch 250/300
# 21/21 [==============================] - 2s 90ms/step - loss: 0.5840 - acc: 0.6978 - val_loss: 0.5879 - val_acc: 0.6971
# Epoch 251/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5779 - acc: 0.7029 - val_loss: 0.5829 - val_acc: 0.7143
# Epoch 252/300
# 21/21 [==============================] - 2s 86ms/step - loss: 0.5803 - acc: 0.7019 - val_loss: 0.5888 - val_acc: 0.7102
# Epoch 253/300
# 21/21 [==============================] - 2s 91ms/step - loss: 0.5759 - acc: 0.7054 - val_loss: 0.5753 - val_acc: 0.7198
# Epoch 254/300
# 21/21 [==============================] - 2s 87ms/step - loss: 0.5828 - acc: 0.7027 - val_loss: 0.5957 - val_acc: 0.7163
# Epoch 255/300
# 21/21 [==============================] - 2s 104ms/step - loss: 0.5822 - acc: 0.6996 - val_loss: 0.5831 - val_acc: 0.7163
# Epoch 256/300
# 21/21 [==============================] - 2s 94ms/step - loss: 0.5764 - acc: 0.7046 - val_loss: 0.5860 - val_acc: 0.7225
# Epoch 257/300
# 21/21 [==============================] - 2s 104ms/step - loss: 0.5751 - acc: 0.7064 - val_loss: 0.5824 - val_acc: 0.7088
# Epoch 258/300
# 21/21 [==============================] - 2s 87ms/step - loss: 0.5763 - acc: 0.7084 - val_loss: 0.5960 - val_acc: 0.7191
# Epoch 259/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5710 - acc: 0.7060 - val_loss: 0.5780 - val_acc: 0.7102
# Epoch 260/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5729 - acc: 0.7020 - val_loss: 0.5876 - val_acc: 0.7109
# Epoch 261/300
# 21/21 [==============================] - 2s 87ms/step - loss: 0.5790 - acc: 0.7007 - val_loss: 0.5794 - val_acc: 0.6964
# Epoch 262/300
# 21/21 [==============================] - 2s 86ms/step - loss: 0.5775 - acc: 0.7084 - val_loss: 0.5851 - val_acc: 0.7170
# Epoch 263/300
# 21/21 [==============================] - 2s 88ms/step - loss: 0.5763 - acc: 0.7027 - val_loss: 0.5791 - val_acc: 0.7232
# Epoch 264/300
# 21/21 [==============================] - 2s 87ms/step - loss: 0.5771 - acc: 0.7098 - val_loss: 0.6127 - val_acc: 0.7040
# Epoch 265/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5755 - acc: 0.7073 - val_loss: 0.5847 - val_acc: 0.7143
# Epoch 266/300
# 21/21 [==============================] - 2s 90ms/step - loss: 0.5794 - acc: 0.7022 - val_loss: 0.5841 - val_acc: 0.7012
# Epoch 267/300
# 21/21 [==============================] - 2s 99ms/step - loss: 0.5757 - acc: 0.7000 - val_loss: 0.5840 - val_acc: 0.7067
# Epoch 268/300
# 21/21 [==============================] - 2s 100ms/step - loss: 0.5753 - acc: 0.7074 - val_loss: 0.5786 - val_acc: 0.7122
# Epoch 269/300
# 21/21 [==============================] - 2s 97ms/step - loss: 0.5801 - acc: 0.7037 - val_loss: 0.5868 - val_acc: 0.7184
# Epoch 270/300
# 21/21 [==============================] - 2s 94ms/step - loss: 0.5833 - acc: 0.7021 - val_loss: 0.5766 - val_acc: 0.7150
# Epoch 271/300
# 21/21 [==============================] - 2s 93ms/step - loss: 0.5768 - acc: 0.7055 - val_loss: 0.5838 - val_acc: 0.7060
# Epoch 272/300
# 21/21 [==============================] - 2s 95ms/step - loss: 0.5783 - acc: 0.7021 - val_loss: 0.5862 - val_acc: 0.7040
# Epoch 273/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5869 - acc: 0.7003 - val_loss: 0.5898 - val_acc: 0.7081
# Epoch 274/300
# 21/21 [==============================] - 2s 91ms/step - loss: 0.5840 - acc: 0.6991 - val_loss: 0.5849 - val_acc: 0.6964
# Epoch 275/300
# 21/21 [==============================] - 2s 105ms/step - loss: 0.5803 - acc: 0.6988 - val_loss: 0.5766 - val_acc: 0.7060
# Epoch 276/300
# 21/21 [==============================] - 2s 101ms/step - loss: 0.5808 - acc: 0.7008 - val_loss: 0.5831 - val_acc: 0.7019
# Epoch 277/300
# 21/21 [==============================] - 2s 92ms/step - loss: 0.5754 - acc: 0.7075 - val_loss: 0.5979 - val_acc: 0.7218
# Epoch 278/300
# 21/21 [==============================] - 2s 95ms/step - loss: 0.5811 - acc: 0.6997 - val_loss: 0.5832 - val_acc: 0.7212
# Epoch 279/300
# 21/21 [==============================] - 2s 89ms/step - loss: 0.5799 - acc: 0.7058 - val_loss: 0.5901 - val_acc: 0.7184
# Epoch 280/300
# 21/21 [==============================] - 2s 84ms/step - loss: 0.5770 - acc: 0.7048 - val_loss: 0.5909 - val_acc: 0.6944
# Epoch 281/300
# 21/21 [==============================] - 2s 88ms/step - loss: 0.5828 - acc: 0.7013 - val_loss: 0.5854 - val_acc: 0.7074
# Epoch 282/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5785 - acc: 0.7071 - val_loss: 0.5868 - val_acc: 0.7109
# Epoch 283/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5742 - acc: 0.7098 - val_loss: 0.5757 - val_acc: 0.7170
# Epoch 284/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5764 - acc: 0.7052 - val_loss: 0.5876 - val_acc: 0.7136
# Epoch 285/300
# 21/21 [==============================] - 2s 85ms/step - loss: 0.5819 - acc: 0.7039 - val_loss: 0.5816 - val_acc: 0.7170
# Epoch 286/300
# 21/21 [==============================] - 2s 86ms/step - loss: 0.5723 - acc: 0.7079 - val_loss: 0.6040 - val_acc: 0.6978
# Epoch 287/300
# 21/21 [==============================] - 2s 97ms/step - loss: 0.5774 - acc: 0.7050 - val_loss: 0.5758 - val_acc: 0.7225
# Epoch 288/300
# 21/21 [==============================] - 2s 96ms/step - loss: 0.5715 - acc: 0.7091 - val_loss: 0.5943 - val_acc: 0.6971
# Epoch 289/300
# 21/21 [==============================] - 2s 107ms/step - loss: 0.5780 - acc: 0.7052 - val_loss: 0.5802 - val_acc: 0.7191
# Epoch 290/300
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5800 - acc: 0.7053 - val_loss: 0.6025 - val_acc: 0.7115
# Epoch 291/300
# 21/21 [==============================] - 2s 99ms/step - loss: 0.5778 - acc: 0.7047 - val_loss: 0.5873 - val_acc: 0.7191
# Epoch 292/300
# 21/21 [==============================] - 2s 98ms/step - loss: 0.5839 - acc: 0.6976 - val_loss: 0.5777 - val_acc: 0.7088
# Epoch 293/300
# 21/21 [==============================] - 2s 96ms/step - loss: 0.5797 - acc: 0.7063 - val_loss: 0.6143 - val_acc: 0.7012
# Epoch 294/300
# 21/21 [==============================] - 2s 90ms/step - loss: 0.5887 - acc: 0.6983 - val_loss: 0.5870 - val_acc: 0.7205
# Epoch 295/300
# 21/21 [==============================] - 2s 94ms/step - loss: 0.5757 - acc: 0.7035 - val_loss: 0.5811 - val_acc: 0.7205

# %% [markdown]
# Let us plot the training history (losses and accuracies for the train and test data).

# %%
sg.utils.plot_history(history)

# %% [markdown]
# Finally, let us calculate the performance of the trained model on the test data.

# %%
test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#   ['...']
# 112/112 [==============================] - 0s 3ms/step - loss: 0.5738 - acc: 0.7157
#
# Test Set Metrics:
# 	loss: 0.5738
# 	acc: 0.7157

# %% [markdown]
# ### Conclusion
#
# We demonstrated the use of `StellarGraph`'s `DeepGraphConvolutionalNeuralNetwork` implementation for supervised graph classification algorithm. More specifically we showed how to  predict whether a chemical compound represented as a graph is an enzyme or not.
#
# There is a small difference with regards to the performance on the same dataset published in [1]; the above training run achieves approximately $72\%$ accuracy whereas [1] reports $75.54\%\pm0.94$. This difference can be attributed to a small number of factors listed below,
# - We use a different training scheme, that is a single 90/10 split of the data as opposed to the 10-fold cross validation scheme used in [1]. We use a single fold for ease of exposition.
# - The experimental evaluation scheme in [1] does not specify some important details such as the regularisation used for the neural network layers; if a bias term is included; the weight initialization method used; and the batch size.

# %% [markdown]
# <table><tr><td>Run the master version of this notebook:</td><td><a href="https://mybinder.org/v2/gh/stellargraph/stellargraph/master?urlpath=lab/tree/demos/graph-classification/dgcnn-graph-classification.ipynb" alt="Open In Binder" target="_parent"><img src="https://mybinder.org/badge_logo.svg"/></a></td><td><a href="https://colab.research.google.com/github/stellargraph/stellargraph/blob/master/demos/graph-classification/dgcnn-graph-classification.ipynb" alt="Open In Colab" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg"/></a></td></tr></table>
