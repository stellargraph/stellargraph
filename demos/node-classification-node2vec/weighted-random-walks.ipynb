# %% [markdown]
# ## Introduction
#
# An example of node classification on a weighted homogeneous graph using the `Node2Vec` representation learning algorithm. The example uses components from the `stellargraph`, `Gensim`, and `scikit-learn` libraries.
#
# **Note:** For clarity of exposition, this notebook forgoes the use of standard machine learning practices such as `Node2Vec` parameter tuning, node feature standarization, data splitting that handles class imbalance, classifier selection, and classifier tuning to maximize predictive accuracy. We leave such improvements to the reader.
#
# ### References
#
# **1.** Node2Vec: Scalable Feature Learning for Networks. A. Grover, J. Leskovec. ACM SIGKDD International Conference on Knowledge Discovery and Data Mining (KDD), 2016. ([link](https://snap.stanford.edu/node2vec/))
#
# **2.** Distributed representations of words and phrases and their compositionality. T. Mikolov, I. Sutskever, K. Chen, G. S. Corrado, and J. Dean.  In Advances in Neural Information Processing Systems (NIPS), pp. 3111-3119, 2013. ([link](https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf))
#
# **3.** Gensim: Topic modelling for humans. ([link](https://radimrehurek.com/gensim/))
#
# **4.** scikit-learn: Machine Learning in Python ([link](http://scikit-learn.org/stable/))

# %%
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import accuracy_score
from sklearn.metrics.pairwise import pairwise_distances


import os
import networkx as nx
import numpy as np
import pandas as pd


from stellargraph.data import BiasedRandomWalk
from stellargraph import StellarGraph

# %matplotlib inline

# %% [markdown]
# ### Dataset
#
#
# The dataset is the citation network Cora.
#
# It can be downloaded by clicking [here](https://linqs-data.soe.ucsc.edu/public/lbc/cora.tgz)
#
# The following is the description of the dataset from the publisher,
#
# > The Cora dataset consists of 2708 scientific publications classified into one of seven classes. The citation network consists of 5429 links. Each publication in the dataset is described by a 0/1-valued word vector indicating the absence/presence of the corresponding word from the dictionary. The dictionary consists of 1433 unique words. The README file in the dataset provides more details.
#
# For this demo, we ignore the word vectors associated with each paper. We are only interested in the network structure and the **subject** attribute of each paper.
#
# Download and unzip the cora.tgz file to a location on your computer.
#
# We assume that the dataset is stored in the directory
#
# `~/data/cora/`
#
# where the files `cora.cites` and `cora.content` can be located.
#
# We are going to load the data into a networkx object.

# %%
data_dir = "~/Documents/data/cora"

# %%
cora_location = os.path.expanduser(os.path.join(data_dir, "cora.cites"))
g_nx_wt = nx.read_weighted_edgelist(path=cora_location)

# load the node attribute data
cora_data_location = os.path.expanduser(os.path.join(data_dir, "cora.content"))
node_attr = pd.read_csv(cora_data_location, sep='\t', header=None)
values = { str(row.tolist()[0]): row.tolist()[-1] for _, row in node_attr.iterrows()}
nx.set_node_attributes(g_nx_wt, values, 'subject')

# Select the largest connected component. For clarity we ignore isolated
# nodes and subgraphs; having these in the data does not prevent the
# algorithm from running and producing valid results.
g_nx_wt = max(nx.connected_component_subgraphs(g_nx_wt, copy=True), key=len)
print("Largest subgraph statistics: {} nodes, {} edges".format(
    g_nx_wt.number_of_nodes(), g_nx_wt.number_of_edges()))
# Out:
# Largest subgraph statistics: 2485 nodes, 5069 edges

# %% [markdown]
# ### Add weights to the edges
# Each edge is weighted by the jaccard similarity of the features of the pair of nodes.

# %%
df = node_attr.copy()

# %%
df.set_index(0, inplace = True)
papers = df.index
wts = pd.DataFrame(1- pairwise_distances(df.iloc[:,:-1],metric = 'jaccard') , index = papers, columns = papers)
sims.index = sims.index.map(str)
sims.columns = sims.columns.map(str)

# %% [markdown]
# Append the weight attribute to the edges.

# %%
for u,v in g_nx_wt.edges():
    val = sims[u][v]
    g_nx_wt[u][v]['weight'] = val

# %%
g_nx_wt.edges(data = True)
# Out:
# EdgeDataView([('35', '1033', {'weight': 0.04761904761904767}), ('35', '103482', {'weight': 0.02564102564102566}), ('35', '103515', {'weight': 0.05128205128205132}), ('35', '1050679', {'weight': 0.23809523809523814}), ('35', '1103960', {'weight': 0.0}), ('35', '1103985', {'weight': 0.05128205128205132}), ('35', '1109199', {'weight': 0.0}), ('35', '1112911', {'weight': 0.05128205128205132}), ('35', '1113438', {'weight': 0.0}), ('35', '1113831', {'weight': 0.02777777777777779}), ('35', '1114331', {'weight': 0.08333333333333337}), ('35', '1117476', {'weight': 0.05128205128205132}), ('35', '1119505', {'weight': 0.07499999999999996}), ('35', '1119708', {'weight': 0.02564102564102566}), ('35', '1120431', {'weight': 0.023255813953488413}), ('35', '1123756', {'weight': 0.04878048780487809}), ('35', '1125386', {'weight': 0.023255813953488413}), ('35', '1127430', {'weight': 0.08333333333333337}), ('35', '1127913', {'weight': 0.0}), ('35', '1128204', {'weight': 0.05128205128205132}), ('35', '1128227', {'weight': 0.07692307692307687}), ('35', '1128314', {'weight': 0.07499999999999996}), ('35', '1128453', {'weight': 0.07317073170731703}), ('35', '1128945', {'weight': 0.0}), ('35', '1128959', {'weight': 0.17142857142857137}), ('35', '1128985', {'weight': 0.0}), ('35', '1129018', {'weight': 0.023809523809523836}), ('35', '1129027', {'weight': 0.04166666666666663}), ('35', '1129573', {'weight': 0.050000000000000044}), ('35', '1129683', {'weight': 0.027027027027026973}), ('35', '1129778', {'weight': 0.02631578947368418}), ('35', '1130847', {'weight': 0.07692307692307687}), ('35', '1130856', {'weight': 0.09523809523809523}), ('35', '1131116', {'weight': 0.10526315789473684}), ('35', '1131360', {'weight': 0.09090909090909094}), ('35', '1131557', {'weight': 0.07894736842105265}), ('35', '1131752', {'weight': 0.05882352941176472}), ('35', '1133196', {'weight': 0.05555555555555558}), ('35', '1133338', {'weight': 0.05882352941176472}), ('35', '1136814', {'weight': 0.10256410256410253}), ('35', '1137466', {'weight': 0.09999999999999998}), ('35', '1152421', {'weight': 0.18181818181818177}), ('35', '1152508', {'weight': 0.08108108108108103}), ('35', '1153065', {'weight': 0.07692307692307687}), ('35', '1153280', {'weight': 0.18181818181818177}), ('35', '1153577', {'weight': 0.08333333333333337}), ('35', '1153853', {'weight': 0.07894736842105265}), ('35', '1153943', {'weight': 0.02777777777777779}), ('35', '1154176', {'weight': 0.0}), ('35', '1154459', {'weight': 0.18181818181818177}), ('35', '116552', {'weight': 0.05128205128205132}), ('35', '12576', {'weight': 0.08571428571428574}), ('35', '128540', {'weight': 0.07692307692307687}), ('35', '132806', {'weight': 0.08571428571428574}), ('35', '135130', {'weight': 0.05405405405405406}), ('35', '141342', {'weight': 0.11764705882352944}), ('35', '141347', {'weight': 0.05128205128205132}), ('35', '148170', {'weight': 0.04878048780487809}), ('35', '15670', {'weight': 0.09090909090909094}), ('35', '1688', {'weight': 0.07692307692307687}), ('35', '175291', {'weight': 0.07317073170731703}), ('35', '178727', {'weight': 0.1428571428571429}), ('35', '18582', {'weight': 0.046511627906976716}), ('35', '190697', {'weight': 0.16216216216216217}), ('35', '190706', {'weight': 0.08108108108108103}), ('35', '1956', {'weight': 0.0}), ('35', '197054', {'weight': 0.0}), ('35', '198443', {'weight': 0.16666666666666663}), ('35', '198653', {'weight': 0.0714285714285714}), ('35', '206371', {'weight': 0.05714285714285716}), ('35', '210871', {'weight': 0.09999999999999998}), ('35', '229635', {'weight': 0.16666666666666663}), ('35', '231249', {'weight': 0.12903225806451613}), ('35', '248425', {'weight': 0.07999999999999996}), ('35', '249421', {'weight': 0.0}), ('35', '254923', {'weight': 0.04761904761904767}), ('35', '259701', {'weight': 0.12903225806451613}), ('35', '259702', {'weight': 0.07894736842105265}), ('35', '263279', {'weight': 0.02564102564102566}), ('35', '263498', {'weight': 0.1428571428571429}), ('35', '265203', {'weight ...

# %% [markdown]
# ### The Node2Vec algorithm
#
# The Node2Vec algorithm introduced in [1] is a 2-step representation learning algorithm. The two steps are,
#
# 1. Use 2nd order random walks to generate sentences from a graph. A sentence is a list of node ids. The set of all sentences makes a corpus.
#
# 2. The corpus is then used to learn an embedding vector for each node in the graph. Each node id is considered a unique word/token in a dictionary that has size equal to the number of nodes in the graph. The Word2Vec algorithm, [2], is used for calculating the embedding vectors.

# %% [markdown]
# ## Corpus generation using random walks
#
# The stellargraph library provides an implementation for 2nd order random walks as required by Node2Vec. The random walks have fixed maximum length and are controlled by two parameters `p` and `q`. See [1] for a detailed description of these parameters.
#
# We are going to start 10 random walks from each node in the graph with a length up to 100. We set parameter `p` to 0.5 and `q` to 2.0.

# %%
list(StellarGraph(g_nx_wt).edges(data = True))
# Out:
# [('35', '1033', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('35', '103482', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('35', '103515', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '1050679', {'weight': 0.23809523809523814, 'label': 'default'}),
#  ('35', '1103960', {'weight': 0.0, 'label': 'default'}),
#  ('35', '1103985', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '1109199', {'weight': 0.0, 'label': 'default'}),
#  ('35', '1112911', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '1113438', {'weight': 0.0, 'label': 'default'}),
#  ('35', '1113831', {'weight': 0.02777777777777779, 'label': 'default'}),
#  ('35', '1114331', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('35', '1117476', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '1119505', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('35', '1119708', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('35', '1120431', {'weight': 0.023255813953488413, 'label': 'default'}),
#  ('35', '1123756', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('35', '1125386', {'weight': 0.023255813953488413, 'label': 'default'}),
#  ('35', '1127430', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('35', '1127913', {'weight': 0.0, 'label': 'default'}),
#  ('35', '1128204', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '1128227', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '1128314', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('35', '1128453', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('35', '1128945', {'weight': 0.0, 'label': 'default'}),
#  ('35', '1128959', {'weight': 0.17142857142857137, 'label': 'default'}),
#  ('35', '1128985', {'weight': 0.0, 'label': 'default'}),
#  ('35', '1129018', {'weight': 0.023809523809523836, 'label': 'default'}),
#  ('35', '1129027', {'weight': 0.04166666666666663, 'label': 'default'}),
#  ('35', '1129573', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('35', '1129683', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('35', '1129778', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('35', '1130847', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '1130856', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('35', '1131116', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('35', '1131360', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('35', '1131557', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('35', '1131752', {'weight': 0.05882352941176472, 'label': 'default'}),
#  ('35', '1133196', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('35', '1133338', {'weight': 0.05882352941176472, 'label': 'default'}),
#  ('35', '1136814', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('35', '1137466', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('35', '1152421', {'weight': 0.18181818181818177, 'label': 'default'}),
#  ('35', '1152508', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('35', '1153065', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '1153280', {'weight': 0.18181818181818177, 'label': 'default'}),
#  ('35', '1153577', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('35', '1153853', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('35', '1153943', {'weight': 0.02777777777777779, 'label': 'default'}),
#  ('35', '1154176', {'weight': 0.0, 'label': 'default'}),
#  ('35', '1154459', {'weight': 0.18181818181818177, 'label': 'default'}),
#  ('35', '116552', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '12576', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('35', '128540', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '132806', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('35', '135130', {'weight': 0.05405405405405406, 'label': 'default'}),
#  ('35', '141342', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('35', '141347', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '148170', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('35', '15670', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('35', '1688', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '175291', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('35', '178727', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('35', '18582', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('35', '190697', {'weight': 0.16216216216216217, 'label': 'default'}),
#  ('35', '190706', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('35', '1956', {'weight': 0.0, 'label': 'default'}),
#  ('35', '197054', {'weight': 0.0, 'label': 'default'}),
#  ('35', '198443', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('35', '198653', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('35', '206371', {'weight': 0.05714285714285716, 'label': 'default'}),
#  ('35', '210871', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('35', '229635', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('35', '231249', {'weight': 0.12903225806451613, 'label': 'default'}),
#  ('35', '248425', {'weight': 0.07999999999999996, 'label': 'default'}),
#  ('35', '249421', {'weight': 0.0, 'label': 'default'}),
#  ('35', '254923', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('35', '259701', {'weight': 0.12903225806451613, 'label': 'default'}),
#  ('35', '259702', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('35', '263279', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('35', '263498', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('35', '265203', {'weight': 0.0, 'label': 'default'}),
#  ('35', '273152', {'weight': 0.15000000000000002, 'label': 'default'}),
#  ('35', '27510', {'weight': 0.0, 'label': 'default'}),
#  ('35', '28290', {'weight': 0.023809523809523836, 'label': 'default'}),
#  ('35', '286500', {'weight': 0.15384615384615385, 'label': 'default'}),
#  ('35', '287787', {'weight': 0.05882352941176472, 'label': 'default'}),
#  ('35', '28851', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('35', '289779', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '289780', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('35', '289781', {'weight': 0.09756097560975607, 'label': 'default'}),
#  ('35', '307015', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('35', '335733', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('35', '33904', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('35', '33907', {'weight': 0.11428571428571432, 'label': 'default'}),
#  ('35', '35061', {'weight': 0.13043478260869568, 'label': 'default'}),
#  ('35', '38205', {'weight': 0.0, 'label': 'default'}),
#  ('35', '387795', {'weight': 0.04166666666666663, 'label': 'default'}),
#  ('35', '415693', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('35', '41714', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('35', '427606', {'weight': 0.13043478260869568, 'label': 'default'}),
#  ('35', '44368', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('35', '45599', {'weight': 0.1842105263157895, 'label': 'default'}),
#  ('35', '46079', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('35', '46431', {'weight': 0.024390243902439046, 'label': 'default'}),
#  ('35', '486840', {'weight': 0.0, 'label': 'default'}),
#  ('35', '48766', {'weight': 0.15625, 'label': 'default'}),
#  ('35', '503883', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('35', '503893', {'weight': 0.15384615384615385, 'label': 'default'}),
#  ('35', '513189', {'weight': 0.08695652173913049, 'label': 'default'}),
#  ('35', '54129', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '54131', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '56119', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('35', '561238', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('35', '568857', {'weight': 0.024390243902439046, 'label': 'default'}),
#  ('35', '573964', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('35', '573978', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('35', '574009', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('35', '574264', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('35', '574462', {'weight': 0.06060606060606055, 'label': 'default'}),
#  ('35', '575077', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('35', '575292', {'weight': 0.19444444444444442, 'label': 'default'}),
#  ('35', '575331', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('35', '576725', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('35', '576795', {'weight': 0.07999999999999996, 'label': 'default'}),
#  ('35', '577227', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('35', '578780', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('35', '579008', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('35', '592973', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('35', '593091', {'weight': 0.13043478260869568, 'label': 'default'}),
#  ('35', '593105', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('35', '593240', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('35', '593260', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('35', '593813', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('35', '594047', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('35', '594543', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('35', '594649', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('35', '594900', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('35', '608326', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('35', '634902', {'weight': 0.15384615384615385, 'label': 'default'}),
#  ('35', '634904', {'weight': 0.05882352941176472, 'label': 'default'}),
#  ('35', '634938', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '634975', {'weight': 0.07999999999999996, 'label': 'default'}),
#  ('35', '640617', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('35', '646809', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('35', '646837', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('35', '647408', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '647447', {'weight': 0.02857142857142858, 'label': 'default'}),
#  ('35', '66556', {'weight': 0.05714285714285716, 'label': 'default'}),
#  ('35', '66563', {'weight': 0.02777777777777779, 'label': 'default'}),
#  ('35', '66805', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('35', '69284', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('35', '69296', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '694759', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('35', '735303', {'weight': 0.023809523809523836, 'label': 'default'}),
#  ('35', '78511', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('35', '787016', {'weight': 0.09756097560975607, 'label': 'default'}),
#  ('35', '801170', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('35', '81722', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('35', '82098', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('35', '84021', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('35', '85352', {'weight': 0.05882352941176472, 'label': 'default'}),
#  ('35', '86359', {'weight': 0.040000000000000036, 'label': 'default'}),
#  ('35', '8865', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('35', '887', {'weight': 0.0, 'label': 'default'}),
#  ('35', '97645', {'weight': 0.08823529411764708, 'label': 'default'}),
#  ('35', '98698', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('35', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('35', '210872', {'weight': 0.1578947368421053, 'label': 'default'}),
#  ('1033', '1034', {'weight': 0.4242424242424242, 'label': 'default'}),
#  ('1033', '1107062', {'weight': 0.16216216216216217, 'label': 'default'}),
#  ('1033', '41714', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('1033', '45605', {'weight': 0.03703703703703709, 'label': 'default'}),
#  ('103482', '1114388', {'weight': 0.0, 'label': 'default'}),
#  ('103482', '1119140', {'weight': 0.0625, 'label': 'default'}),
#  ('103482', '1128990', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('103482', '27510', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('103482', '27514', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('103515', '8865', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('103515', '1113742', {'weight': 0.11428571428571432, 'label': 'default'}),
#  ('103515', '1127913', {'weight': 0.0357142857142857, 'label': 'default'}),
#  ('103515', '1128314', {'weight': 0.0, 'label': 'default'}),
#  ('103515', '1129778', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('103515', '1153853', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('103515', '246618', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('103515', '459214', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('103515', '54131', {'weight': 0.024390243902439046, 'label': 'default'}),
#  ('103515', '575402', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('1050679', '3229', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('1050679', '35797', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('1050679', '427606', {'weight': 0.19999999999999996, 'label': 'default'}),
#  ('1103960', '3229', {'weight': 0.0, 'label': 'default'}),
#  ('1103960', '33895', {'weight': 0.0, 'label': 'default'}),
#  ('1103960', '33904', {'weight': 0.0, 'label': 'default'}),
#  ('1103960', '33907', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('1103985', '1688', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('1109199', '6214', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('1109199', '148170', {'weight': 0.17948717948717952, 'label': 'default'}),
#  ('1112911', '887', {'weight': 0.0, 'label': 'default'}),
#  ('1112911', '22229', {'weight': 0.09302325581395354, 'label': 'default'}),
#  ('1112911', '144701', {'weight': 0.12195121951219512, 'label': 'default'}),
#  ('1113438', '35061', {'weight': 0.03703703703703709, 'label': 'default'}),
#  ('1113438', '35852', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('1113438', '141324', {'weight': 0.023255813953488413, 'label': 'default'}),
#  ('1113438', '240791', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('1113831', '248425', {'weight': 0.0, 'label': 'default'}),
#  ('1113831', '248431', {'weight': 0.0, 'label': 'default'}),
#  ('1114331', '85352', {'weight': 0.09375, 'label': 'default'}),
#  ('1114331', '134199', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('1114331', '259701', {'weight': 0.09677419354838712, 'label': 'default'}),
#  ('1114331', '259702', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('1117476', '54132', {'weight': 0.17948717948717952, 'label': 'default'}),
#  ('1117476', '210871', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('1119505', '375605', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('1119708', '14062', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('1119708', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('1119708', '141342', {'weight': 0.0, 'label': 'default'}),
#  ('1119708', '141347', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('1120431', '13656', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('1120431', '13658', {'weight': 0.11904761904761907, 'label': 'default'}),
#  ('1120431', '13686', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('1123756', '28230', {'weight': 0.03703703703703709, 'label': 'default'}),
#  ('1123756', '124952', {'weight': 0.14634146341463417, 'label': 'default'}),
#  ('1123756', '287787', {'weight': 0.0, 'label': 'default'}),
#  ('1125386', '1955', {'weight': 0.0, 'label': 'default'}),
#  ('1125386', '3231', {'weight': 0.022222222222222254, 'label': 'default'}),
#  ('1125386', '238401', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('1127430', '85352', {'weight': 0.06060606060606055, 'label': 'default'}),
#  ('1127913', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('1127913', '231249', {'weight': 0.0, 'label': 'default'}),
#  ('1128204', '58758', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('1128227', '44368', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('1128227', '220420', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('1128227', '577331', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('1128314', '579108', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('1128453', '87417', {'weight': 0.06976744186046513, 'label': 'default'}),
#  ('1128453', '289780', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('1128453', '289781', {'weight': 0.11363636363636365, 'label': 'default'}),
#  ('1128959', '56709', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('1128985', '44455', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('1128985', '54132', {'weight': 0.0, 'label': 'default'}),
#  ('1128985', '227178', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('1129018', '94641', {'weight': 0.09302325581395354, 'label': 'default'}),
#  ('1129027', '85352', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('1129573', '12576', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('1129573', '56115', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('1129683', '12337', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('1129683', '70970', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('1129683', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('1129683', '608326', {'weight': 0.16216216216216217, 'label': 'default'}),
#  ('1129778', '66556', {'weight': 0.0, 'label': 'default'}),
#  ('1129778', '575402', {'weight': 0.02857142857142858, 'label': 'default'}),
#  ('1130847', '287787', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('1130847', '634938', {'weight': 0.8333333333333334, 'label': 'default'}),
#  ('1130856', '287787', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('1131116', '148341', {'weight': 0.0444444444444444, 'label': 'default'}),
#  ('1131116', '259702', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('1131116', '263069', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('1131360', '1688', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('1131360', '307656', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('1131360', '646900', {'weight': 0.2222222222222222, 'label': 'default'}),
#  ('1131557', '286513', {'weight': 0.303030303030303, 'label': 'default'}),
#  ('1131752', '577227', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('1133196', '175256', {'weight': 0.0, 'label': 'default'}),
#  ('1133338', '1688', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('1136814', '1688', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('1136814', '33907', {'weight': 0.19999999999999996, 'label': 'default'}),
#  ('1152421', '14062', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('1152421', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('1152421', '85352', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('1153065', '1688', {'weight': 0.03448275862068961, 'label': 'default'}),
#  ('1153280', '14062', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('1153280', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('1153280', '85352', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('1153577', '33895', {'weight': 0.0, 'label': 'default'}),
#  ('1153577', '503877', {'weight': 0.07999999999999996, 'label': 'default'}),
#  ('1153577', '503883', {'weight': 0.0, 'label': 'default'}),
#  ('1153577', '503893', {'weight': 0.14814814814814814, 'label': 'default'}),
#  ('1153853', '108047', {'weight': 0.0, 'label': 'default'}),
#  ('1153853', '578650', {'weight': 0.03703703703703709, 'label': 'default'}),
#  ('1153943', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('1153943', '85352', {'weight': 0.0, 'label': 'default'}),
#  ('1153943', '97390', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('1153943', '576257', {'weight': 0.0, 'label': 'default'}),
#  ('1154176', '33895', {'weight': 0.0, 'label': 'default'}),
#  ('1154459', '14062', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('1154459', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('1154459', '85352', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('116552', '40', {'weight': 0.05405405405405406, 'label': 'default'}),
#  ('116552', '116553', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('116552', '246618', {'weight': 0.17647058823529416, 'label': 'default'}),
#  ('12576', '887', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('12576', '6213', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('12576', '1071981', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('12576', '1104999', {'weight': 0.11428571428571432, 'label': 'default'}),
#  ('12576', '1105221', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('12576', '1107674', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('12576', '127033', {'weight': 0.16129032258064513, 'label': 'default'}),
#  ('12576', '135130', {'weight': 0.08823529411764708, 'label': 'default'}),
#  ('12576', '229635', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('12576', '28290', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('12576', '416455', {'weight': 0.21875, 'label': 'default'}),
#  ('12576', '56112', {'weight': 0.5185185185185186, 'label': 'default'}),
#  ('12576', '56119', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('12576', '56709', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('12576', '574710', {'weight': 0.1351351351351351, 'label': 'default'}),
#  ('12576', '575795', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('12576', '62718', {'weight': 0.05714285714285716, 'label': 'default'}),
#  ('12576', '63832', {'weight': 0.1351351351351351, 'label': 'default'}),
#  ('12576', '83725', {'weight': 0.2222222222222222, 'label': 'default'}),
#  ('12576', '8875', {'weight': 0.12121212121212122, 'label': 'default'}),
#  ('128540', '28287', {'weight': 0.13888888888888884, 'label': 'default'}),
#  ('128540', '44455', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('128540', '387795', {'weight': 0.125, 'label': 'default'}),
#  ('132806', '4584', {'weight': 0.05405405405405406, 'label': 'default'}),
#  ('132806', '45599', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('132806', '48766', {'weight': 0.09375, 'label': 'default'}),
#  ('132806', '593260', {'weight': 0.2142857142857143, 'label': 'default'}),
#  ('135130', '56115', {'weight': 0.15000000000000002, 'label': 'default'}),
#  ('135130', '1105221', {'weight': 0.1351351351351351, 'label': 'default'}),
#  ('135130', '416455', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('135130', '574710', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('141342', '35061', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('141342', '40', {'weight': 0.125, 'label': 'default'}),
#  ('141342', '575292', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('141342', '608191', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('141342', '70970', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('141342', '78511', {'weight': 0.12121212121212122, 'label': 'default'}),
#  ('141347', '14062', {'weight': 0.15625, 'label': 'default'}),
#  ('148170', '1128997', {'weight': 0.022222222222222254, 'label': 'default'}),
#  ('15670', '12558', {'weight': 0.0357142857142857, 'label': 'default'}),
#  ('1688', '1134022', {'weight': 0.0, 'label': 'default'}),
#  ('1688', '152483', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('1688', '1694', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('1688', '39474', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('1688', '44368', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('1688', '576725', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('1688', '647413', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('1688', '69284', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('1688', '694759', {'weight': 0.024390243902439046, 'label': 'default'}),
#  ('1688', '84021', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('1688', '58758', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('175291', '2653', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('175291', '8617', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('175291', '8619', {'weight': 0.06896551724137934, 'label': 'default'}),
#  ('175291', '31105', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('175291', '52784', {'weight': 0.19512195121951215, 'label': 'default'}),
#  ('178727', '1110546', {'weight': 0.04166666666666663, 'label': 'default'}),
#  ('18582', '8875', {'weight': 0.023255813953488413, 'label': 'default'}),
#  ('18582', '84021', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('190697', '22229', {'weight': 0.04255319148936165, 'label': 'default'}),
#  ('190697', '41714', {'weight': 0.13888888888888884, 'label': 'default'}),
#  ('190697', '190698', {'weight': 0.14814814814814814, 'label': 'default'}),
#  ('190697', '198443', {'weight': 0.25, 'label': 'default'}),
#  ('190706', '41714', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('190706', '45605', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('190706', '144212', {'weight': 0.13157894736842102, 'label': 'default'}),
#  ('190706', '182094', {'weight': 0.08695652173913049, 'label': 'default'}),
#  ('1956', '936', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('1956', '1955', {'weight': 0.06060606060606055, 'label': 'default'}),
#  ('1956', '101143', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('1956', '1111899', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('1956', '1118302', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('1956', '1153101', {'weight': 0.06060606060606055, 'label': 'default'}),
#  ('1956', '1153150', {'weight': 0.06060606060606055, 'label': 'default'}),
#  ('1956', '1817', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('1956', '263486', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('1956', '83449', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('1956', '3828', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('197054', '8872', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('197054', '41714', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('197054', '182093', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('197054', '182094', {'weight': 0.08695652173913049, 'label': 'default'}),
#  ('197054', '1125092', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('198443', '13658', {'weight': 0.125, 'label': 'default'}),
#  ('198443', '119686', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('198443', '190698', {'weight': 0.15384615384615385, 'label': 'default'}),
#  ('198653', '1113551', {'weight': 0.04166666666666663, 'label': 'default'}),
#  ('198653', '1130539', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('198653', '1152896', {'weight': 0.06666666666666665, 'label': 'default'}),
#  ('198653', '3084', {'weight': 0.07407407407407407, 'label': 'default'}),
#  ('198653', '887', {'weight': 0.15384615384615385, 'label': 'default'}),
#  ('198653', '210871', {'weight': 0.0, 'label': 'default'}),
#  ('206371', '69284', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('206371', '69296', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('210871', '35061', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '44514', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '1128151', {'weight': 0.04166666666666663, 'label': 'default'}),
#  ('210871', '1129629', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '273152', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '38205', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '568857', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '575077', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '595157', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '59715', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '81714', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('210871', '887', {'weight': 0.0, 'label': 'default'}),
#  ('210871', '210872', {'weight': 0.0, 'label': 'default'}),
#  ('229635', '8872', {'weight': 0.19444444444444442, 'label': 'default'}),
#  ('231249', '1125492', {'weight': 0.2068965517241379, 'label': 'default'}),
#  ('248425', '1121398', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('248425', '592975', {'weight': 0.038461538461538436, 'label': 'default'}),
#  ('248425', '594387', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('248425', '579008', {'weight': 0.07999999999999996, 'label': 'default'}),
#  ('249421', '18313', {'weight': 0.0, 'label': 'default'}),
#  ('249421', '219446', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('249421', '1127812', {'weight': 0.03703703703703709, 'label': 'default'}),
#  ('249421', '567018', {'weight': 0.13636363636363635, 'label': 'default'}),
#  ('254923', '1272', {'weight': 0.03125, 'label': 'default'}),
#  ('254923', '108047', {'weight': 0.0, 'label': 'default'}),
#  ('254923', '444240', {'weight': 0.2432432432432432, 'label': 'default'}),
#  ('254923', '415693', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('259702', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('259702', '640617', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('263279', '3231', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('263279', '8224', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('263279', '84021', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('263279', '1114502', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('263498', '35061', {'weight': 0.18181818181818177, 'label': 'default'}),
#  ('263498', '1152761', {'weight': 0.125, 'label': 'default'}),
#  ('263498', '1153860', {'weight': 0.125, 'label': 'default'}),
#  ('265203', '887', {'weight': 0.0, 'label': 'default'}),
#  ('265203', '86359', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('273152', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('273152', '210872', {'weight': 0.038461538461538436, 'label': 'default'}),
#  ('27510', '1110998', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('27510', '1128990', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('27510', '1152143', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('27510', '188318', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('28290', '1104999', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('28290', '1107674', {'weight': 0.040000000000000036, 'label': 'default'}),
#  ('28290', '28287', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('28290', '308529', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('28290', '56709', {'weight': 0.09756097560975607, 'label': 'default'}),
#  ('28290', '63832', {'weight': 0.09302325581395354, 'label': 'default'}),
#  ('286500', '16485', {'weight': 0.06666666666666665, 'label': 'default'}),
#  ('286500', '576362', {'weight': 0.021276595744680882, 'label': 'default'}),
#  ('287787', '110041', {'weight': 0.13793103448275867, 'label': 'default'}),
#  ('287787', '415693', {'weight': 0.0625, 'label': 'default'}),
#  ('287787', '503883', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('287787', '634902', {'weight': 0.040000000000000036, 'label': 'default'}),
#  ('287787', '634904', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('287787', '634938', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('287787', '634975', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('287787', '647447', {'weight': 0.06666666666666665, 'label': 'default'}),
#  ('28851', '54131', {'weight': 0.17142857142857137, 'label': 'default'}),
#  ('28851', '578669', {'weight': 0.33333333333333337, 'label': 'default'}),
#  ('28851', '595157', {'weight': 0.19999999999999996, 'label': 'default'}),
#  ('289779', '87417', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('289779', '289780', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('289779', '801170', {'weight': 0.375, 'label': 'default'}),
#  ('289780', '87417', {'weight': 0.040000000000000036, 'label': 'default'}),
#  ('289780', '1153784', {'weight': 0.0, 'label': 'default'}),
#  ('289780', '801170', {'weight': 0.040000000000000036, 'label': 'default'}),
#  ('289780', '289781', {'weight': 0.07407407407407407, 'label': 'default'}),
#  ('289781', '87417', {'weight': 0.11904761904761907, 'label': 'default'}),
#  ('289781', '1153784', {'weight': 0.0, 'label': 'default'}),
#  ('289781', '801170', {'weight': 0.3055555555555556, 'label': 'default'}),
#  ('307015', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('307015', '1131198', {'weight': 0.02777777777777779, 'label': 'default'}),
#  ('307015', '335733', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('307015', '39474', {'weight': 0.024390243902439046, 'label': 'default'}),
#  ('307015', '643199', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('335733', '643199', {'weight': 0.8260869565217391, 'label': 'default'}),
#  ('33904', '33895', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('33904', '1110546', {'weight': 0.11428571428571432, 'label': 'default'}),
#  ('33904', '503893', {'weight': 0.22857142857142854, 'label': 'default'}),
#  ('33907', '14062', {'weight': 0.12903225806451613, 'label': 'default'}),
#  ('33907', '1134022', {'weight': 0.0, 'label': 'default'}),
#  ('33907', '593091', {'weight': 0.13636363636363635, 'label': 'default'}),
#  ('33907', '593813', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('33907', '97390', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('33907', '97645', {'weight': 0.125, 'label': 'default'}),
#  ('35061', '32083', {'weight': 0.07407407407407407, 'label': 'default'}),
#  ('35061', '1152761', {'weight': 0.375, 'label': 'default'}),
#  ('35061', '1153860', {'weight': 0.375, 'label': 'default'}),
#  ('35061', '144701', {'weight': 0.1071428571428571, 'label': 'default'}),
#  ('35061', '22229', {'weight': 0.06666666666666665, 'label': 'default'}),
#  ('35061', '240791', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('35061', '45605', {'weight': 0.25, 'label': 'default'}),
#  ('35061', '48766', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('35061', '503871', {'weight': 0.125, 'label': 'default'}),
#  ('35061', '682815', {'weight': 0.07407407407407407, 'label': 'default'}),
#  ('38205', '887', {'weight': 0.0, 'label': 'default'}),
#  ('38205', '108047', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('38205', '1128997', {'weight': 0.03125, 'label': 'default'}),
#  ('38205', '1129610', {'weight': 0.0, 'label': 'default'}),
#  ('38205', '1153942', {'weight': 0.0, 'label': 'default'}),
#  ('38205', '117316', {'weight': 0.032258064516129004, 'label': 'default'}),
#  ('38205', '592975', {'weight': 0.0, 'label': 'default'}),
#  ('38205', '592986', {'weight': 0.0, 'label': 'default'}),
#  ('38205', '593060', {'weight': 0.0, 'label': 'default'}),
#  ('38205', '595056', {'weight': 0.040000000000000036, 'label': 'default'}),
#  ('38205', '606647', {'weight': 0.03703703703703709, 'label': 'default'}),
#  ('38205', '61069', {'weight': 0.0, 'label': 'default'}),
#  ('387795', '28287', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('387795', '44455', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('415693', '84021', {'weight': 0.1875, 'label': 'default'}),
#  ('41714', '1110515', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('41714', '144212', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('41714', '182094', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('41714', '44455', {'weight': 0.7619047619047619, 'label': 'default'}),
#  ('41714', '568857', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('41714', '594047', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('41714', '61069', {'weight': 0.06060606060606055, 'label': 'default'}),
#  ('427606', '1131634', {'weight': 0.11538461538461542, 'label': 'default'}),
#  ('427606', '1138968', {'weight': 0.12, 'label': 'default'}),
#  ('427606', '62329', {'weight': 0.375, 'label': 'default'}),
#  ('44368', '14062', {'weight': 0.125, 'label': 'default'}),
#  ('46079', '1152569', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('46079', '69284', {'weight': 0.040000000000000036, 'label': 'default'}),
#  ('46431', '3231', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('46431', '6334', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('46431', '199571', {'weight': 0.023255813953488413, 'label': 'default'}),
#  ('486840', '35852', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('486840', '1128975', {'weight': 0.0, 'label': 'default'}),
#  ('486840', '595063', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('48766', '1104647', {'weight': 0.06060606060606055, 'label': 'default'}),
#  ('48766', '595056', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('503883', '1131374', {'weight': 0.16000000000000003, 'label': 'default'}),
#  ('503883', '1154076', {'weight': 0.17647058823529416, 'label': 'default'}),
#  ('503883', '577331', {'weight': 0.18181818181818177, 'label': 'default'}),
#  ('503883', '646809', {'weight': 0.5, 'label': 'default'}),
#  ('503883', '646836', {'weight': 0.11904761904761907, 'label': 'default'}),
#  ('503883', '646913', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('503883', '647413', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('503883', '647447', {'weight': 0.22580645161290325, 'label': 'default'}),
#  ('503893', '134219', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('503893', '646837', {'weight': 0.07407407407407407, 'label': 'default'}),
#  ('513189', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('513189', '1125597', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('513189', '573964', {'weight': 0.07407407407407407, 'label': 'default'}),
#  ('513189', '576691', {'weight': 0.07407407407407407, 'label': 'default'}),
#  ('513189', '787016', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('54129', '108047', {'weight': 0.0, 'label': 'default'}),
#  ('54129', '1128291', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('54129', '1128319', {'weight': 0.0, 'label': 'default'}),
#  ('54129', '1136791', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('54129', '117315', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('54129', '117316', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('54129', '17477', {'weight': 0.25, 'label': 'default'}),
#  ('54129', '28336', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('54129', '578645', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('54129', '578646', {'weight': 0.25, 'label': 'default'}),
#  ('54129', '578649', {'weight': 0.1282051282051282, 'label': 'default'}),
#  ('54129', '578780', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('54129', '593022', {'weight': 0.05405405405405406, 'label': 'default'}),
#  ('54129', '594543', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('54131', '1128982', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('54131', '1153897', {'weight': 0.0444444444444444, 'label': 'default'}),
#  ('54131', '141324', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('54131', '243483', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('54131', '459213', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('54131', '459214', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('54131', '578780', {'weight': 0.17647058823529416, 'label': 'default'}),
#  ('54131', '593859', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('54131', '593942', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('54131', '59715', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('54131', '66563', {'weight': 0.1515151515151515, 'label': 'default'}),
#  ('54131', '66556', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('56119', '56112', {'weight': 0.06521739130434778, 'label': 'default'}),
#  ('56119', '56115', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('56119', '1104999', {'weight': 0.20512820512820518, 'label': 'default'}),
#  ('56119', '1105221', {'weight': 0.11363636363636365, 'label': 'default'}),
#  ('56119', '127033', {'weight': 0.2222222222222222, 'label': 'default'}),
#  ('56119', '63832', {'weight': 0.08695652173913049, 'label': 'default'}),
#  ('56119', '83725', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('561238', '85352', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('568857', '44455', {'weight': 0.13888888888888884, 'label': 'default'}),
#  ('568857', '1129629', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('568857', '1153816', {'weight': 0.0, 'label': 'default'}),
#  ('568857', '576362', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('573964', '576691', {'weight': 0.1707317073170732, 'label': 'default'}),
#  ('573964', '787016', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('573978', '82920', {'weight': 0.08695652173913049, 'label': 'default'}),
#  ('573978', '787016', {'weight': 0.14634146341463417, 'label': 'default'}),
#  ('574009', '594900', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('574264', '576795', {'weight': 0.125, 'label': 'default'}),
#  ('574264', '815096', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('574462', '85352', {'weight': 0.06896551724137934, 'label': 'default'}),
#  ('575077', '117316', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('575077', '579008', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('575077', '593544', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('575077', '594649', {'weight': 0.023809523809523836, 'label': 'default'}),
#  ('575077', '608190', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('575077', '608191', {'weight': 0.023255813953488413, 'label': 'default'}),
#  ('575077', '66556', {'weight': 0.05882352941176472, 'label': 'default'}),
#  ('575077', '94641', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('575292', '85299', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('575292', '1131734', {'weight': 0.1282051282051282, 'label': 'default'}),
#  ('575292', '1138968', {'weight': 0.125, 'label': 'default'}),
#  ('575331', '98693', {'weight': 0.1071428571428571, 'label': 'default'}),
#  ('576725', '576795', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('576795', '1128201', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('578780', '54132', {'weight': 0.1282051282051282, 'label': 'default'}),
#  ('579008', '54132', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('579008', '1128943', {'weight': 0.15625, 'label': 'default'}),
#  ('579008', '1128978', {'weight': 0.1515151515151515, 'label': 'default'}),
#  ('579008', '593921', {'weight': 0.024390243902439046, 'label': 'default'}),
#  ('579008', '594387', {'weight': 0.19444444444444442, 'label': 'default'}),
#  ('592973', '592975', {'weight': 0.23529411764705888, 'label': 'default'}),
#  ('592973', '592986', {'weight': 0.20588235294117652, 'label': 'default'}),
#  ('593091', '85352', {'weight': 0.1578947368421053, 'label': 'default'}),
#  ('593091', '97645', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('593091', '152483', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('593091', '593248', {'weight': 0.19999999999999996, 'label': 'default'}),
#  ('593105', '22229', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('593105', '94639', {'weight': 0.23333333333333328, 'label': 'default'}),
#  ('593105', '592993', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('593240', '227178', {'weight': 0.022727272727272707, 'label': 'default'}),
#  ('593240', '578845', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('593240', '593155', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('593240', '1136791', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('593240', '593210', {'weight': 0.13888888888888884, 'label': 'default'}),
#  ('593260', '210872', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('593813', '33895', {'weight': 0.125, 'label': 'default'}),
#  ('593813', '94639', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('594047', '1129629', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('594047', '650834', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('594649', '576257', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('594649', '593201', {'weight': 0.17500000000000004, 'label': 'default'}),
#  ('608326', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('608326', '1131611', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('634902', '634975', {'weight': 0.0625, 'label': 'default'}),
#  ('634904', '634975', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('640617', '85352', {'weight': 0.09375, 'label': 'default'}),
#  ('646809', '8874', {'weight': 0.05405405405405406, 'label': 'default'}),
#  ('646809', '1131374', {'weight': 0.125, 'label': 'default'}),
#  ('646809', '1154076', {'weight': 0.1875, 'label': 'default'}),
#  ('646809', '646913', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('647408', '8865', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('647408', '57119', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('647447', '8874', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('647447', '577331', {'weight': 0.1785714285714286, 'label': 'default'}),
#  ('66556', '141324', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('66556', '593859', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('66556', '66563', {'weight': 0.09677419354838712, 'label': 'default'}),
#  ('66556', '85352', {'weight': 0.06451612903225812, 'label': 'default'}),
#  ('66563', '1123530', {'weight': 0.10344827586206895, 'label': 'default'}),
#  ('66563', '96845', {'weight': 0.023255813953488413, 'label': 'default'}),
#  ('66563', '66564', {'weight': 0.27586206896551724, 'label': 'default'}),
#  ('66805', '509315', {'weight': 0.0444444444444444, 'label': 'default'}),
#  ('66805', '82090', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('66805', '89547', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('69284', '56115', {'weight': 0.25, 'label': 'default'}),
#  ('69284', '58758', {'weight': 0.08695652173913049, 'label': 'default'}),
#  ('69284', '69296', {'weight': 0.07999999999999996, 'label': 'default'}),
#  ('69296', '178718', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('735303', '78511', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('735303', '735311', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('78511', '575402', {'weight': 0.125, 'label': 'default'}),
#  ('78511', '9586', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('78511', '78552', {'weight': 0.05714285714285716, 'label': 'default'}),
#  ('78511', '78557', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('801170', '87417', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('81722', '81714', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('82098', '3229', {'weight': 0.0, 'label': 'default'}),
#  ('82098', '82087', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('84021', '82920', {'weight': 0.0, 'label': 'default'}),
#  ('84021', '1106298', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('84021', '1133047', {'weight': 0.17142857142857137, 'label': 'default'}),
#  ('84021', '509233', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('84021', '98698', {'weight': 0.5769230769230769, 'label': 'default'}),
#  ('84021', '143323', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('85352', '152483', {'weight': 0.09090909090909094, 'label': 'default'}),
#  ('85352', '576691', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('85352', '577086', {'weight': 0.033333333333333326, 'label': 'default'}),
#  ('85352', '682815', {'weight': 0.08333333333333337, 'label': 'default'}),
# ...
#  ('1126029', '27623', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('124064', '4584', {'weight': 0.06818181818181823, 'label': 'default'}),
#  ('124064', '6213', {'weight': 0.06521739130434778, 'label': 'default'}),
#  ('124064', '6214', {'weight': 0.19444444444444442, 'label': 'default'}),
#  ('124064', '28542', {'weight': 0.06818181818181823, 'label': 'default'}),
#  ('124064', '6163', {'weight': 0.20512820512820518, 'label': 'default'}),
#  ('124064', '6220', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('124064', '6224', {'weight': 0.19999999999999996, 'label': 'default'}),
#  ('128', '20526', {'weight': 0.13888888888888884, 'label': 'default'}),
#  ('128', '39403', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('128', '91975', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('128', '4584', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('128', '6213', {'weight': 0.023809523809523836, 'label': 'default'}),
#  ('128', '28487', {'weight': 0.25, 'label': 'default'}),
#  ('130', '13960', {'weight': 0.13157894736842102, 'label': 'default'}),
#  ('130', '345340', {'weight': 0.19444444444444442, 'label': 'default'}),
#  ('130', '39403', {'weight': 0.19999999999999996, 'label': 'default'}),
#  ('130', '6163', {'weight': 0.13157894736842102, 'label': 'default'}),
#  ('130', '36802', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('136665', '23258', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('193742', '4584', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('193742', '6151', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('193742', '6213', {'weight': 0.02941176470588236, 'label': 'default'}),
#  ('193742', '1111230', {'weight': 0.07999999999999996, 'label': 'default'}),
#  ('193742', '6152', {'weight': 0.06451612903225812, 'label': 'default'}),
#  ('23258', '6214', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('23258', '1106052', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('23258', '168410', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('23258', '18251', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('23258', '28485', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('23258', '85299', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('28227', '6213', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('28227', '20526', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('28227', '6169', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('28227', '28350', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('28287', '4584', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('28287', '1106547', {'weight': 0.12121212121212122, 'label': 'default'}),
#  ('28287', '1107355', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('28287', '1385', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('28287', '308529', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('28287', '567005', {'weight': 0.05882352941176472, 'label': 'default'}),
#  ('28287', '56709', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('28287', '56708', {'weight': 0.13043478260869568, 'label': 'default'}),
#  ('28350', '6213', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('28350', '1109957', {'weight': 0.05714285714285716, 'label': 'default'}),
#  ('28350', '1113459', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('28350', '1129243', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('28350', '13193', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('28350', '241133', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('28350', '341188', {'weight': 0.024390243902439046, 'label': 'default'}),
#  ('28350', '6210', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('28350', '6220', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('28350', '628667', {'weight': 0.0, 'label': 'default'}),
#  ('28350', '628668', {'weight': 0.025000000000000022, 'label': 'default'}),
#  ('28350', '95579', {'weight': 0.02941176470588236, 'label': 'default'}),
#  ('28387', '117', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('28387', '6196', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('28387', '6224', {'weight': 0.1842105263157895, 'label': 'default'}),
#  ('28387', '1107312', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('28471', '117', {'weight': 0.125, 'label': 'default'}),
#  ('28471', '6213', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('28471', '91975', {'weight': 0.3939393939393939, 'label': 'default'}),
#  ('28471', '89547', {'weight': 0.1578947368421053, 'label': 'default'}),
#  ('28485', '6209', {'weight': 0.21621621621621623, 'label': 'default'}),
#  ('28485', '6213', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('28485', '168410', {'weight': 0.11428571428571432, 'label': 'default'}),
#  ('341188', '117', {'weight': 0.1282051282051282, 'label': 'default'}),
#  ('341188', '7419', {'weight': 0.0, 'label': 'default'}),
#  ('341188', '28491', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('341188', '682666', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('38480', '117', {'weight': 0.027027027027026973, 'label': 'default'}),
#  ('38480', '6209', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('38480', '6213', {'weight': 0.13888888888888884, 'label': 'default'}),
#  ('38480', '6214', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('38480', '1104182', {'weight': 0.023809523809523836, 'label': 'default'}),
#  ('39403', '117', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('434', '267003', {'weight': 0.022222222222222254, 'label': 'default'}),
#  ('434', '4649', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('434', '6213', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('434', '8703', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('434', '10798', {'weight': 0.033333333333333326, 'label': 'default'}),
#  ('55968', '6213', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('55968', '6385', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('55968', '27631', {'weight': 0.10810810810810811, 'label': 'default'}),
#  ('55968', '892139', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('58540', '6196', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('58540', '6213', {'weight': 0.13157894736842102, 'label': 'default'}),
#  ('58540', '181782', {'weight': 0.16666666666666663, 'label': 'default'}),
#  ('6155', '4584', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('6155', '6151', {'weight': 0.05714285714285716, 'label': 'default'}),
#  ('6155', '6213', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('6155', '6214', {'weight': 0.19999999999999996, 'label': 'default'}),
#  ('6170', '117', {'weight': 0.0, 'label': 'default'}),
#  ('6196', '4584', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('6196', '1120731', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('6196', '1153056', {'weight': 0.0, 'label': 'default'}),
#  ('6196', '81350', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('6196', '976334', {'weight': 0.05405405405405406, 'label': 'default'}),
#  ('6196', '6214', {'weight': 0.09375, 'label': 'default'}),
#  ('6220', '6213', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('6220', '134128', {'weight': 0.1515151515151515, 'label': 'default'}),
#  ('6220', '6163', {'weight': 0.19444444444444442, 'label': 'default'}),
#  ('6220', '6224', {'weight': 0.07317073170731703, 'label': 'default'}),
#  ('6220', '28412', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('7432', '23774', {'weight': 0.1351351351351351, 'label': 'default'}),
#  ('755217', '910', {'weight': 0.0, 'label': 'default'}),
#  ('755217', '6213', {'weight': 0.0, 'label': 'default'}),
#  ('755217', '13193', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('755217', '13195', {'weight': 0.1470588235294118, 'label': 'default'}),
#  ('8213', '6209', {'weight': 0.19444444444444442, 'label': 'default'}),
#  ('8213', '28487', {'weight': 0.04166666666666663, 'label': 'default'}),
#  ('91975', '6213', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('91975', '89547', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('91975', '1113459', {'weight': 0.19444444444444442, 'label': 'default'}),
#  ('976334', '4584', {'weight': 0.024390243902439046, 'label': 'default'}),
#  ('976334', '6216', {'weight': 0.12195121951219512, 'label': 'default'}),
#  ('117', '1109581', {'weight': 0.18181818181818177, 'label': 'default'}),
#  ('117', '149669', {'weight': 0.0, 'label': 'default'}),
#  ('117', '17476', {'weight': 0.13157894736842102, 'label': 'default'}),
#  ('117', '189708', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('117', '206259', {'weight': 0.08108108108108103, 'label': 'default'}),
#  ('117', '28202', {'weight': 0.06666666666666665, 'label': 'default'}),
#  ('117', '28278', {'weight': 0.0, 'label': 'default'}),
#  ('117', '32872', {'weight': 0.17142857142857137, 'label': 'default'}),
#  ('117', '33013', {'weight': 0.022727272727272707, 'label': 'default'}),
#  ('117', '6214', {'weight': 0.02777777777777779, 'label': 'default'}),
#  ('117', '75674', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('1109581', '1919', {'weight': 0.0, 'label': 'default'}),
#  ('1109581', '7419', {'weight': 0.0, 'label': 'default'}),
#  ('1109581', '24530', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('1109581', '156794', {'weight': 0.33333333333333337, 'label': 'default'}),
#  ('149669', '6214', {'weight': 0.0, 'label': 'default'}),
#  ('149669', '39890', {'weight': 0.0, 'label': 'default'}),
#  ('149669', '589923', {'weight': 0.0, 'label': 'default'}),
#  ('149669', '189708', {'weight': 0.07407407407407407, 'label': 'default'}),
#  ('17476', '6385', {'weight': 0.15384615384615385, 'label': 'default'}),
#  ('17476', '13269', {'weight': 0.021739130434782594, 'label': 'default'}),
#  ('17476', '1103162', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('17476', '1105033', {'weight': 0.125, 'label': 'default'}),
#  ('17476', '1122425', {'weight': 0.13888888888888884, 'label': 'default'}),
#  ('17476', '1129208', {'weight': 0.0, 'label': 'default'}),
#  ('17476', '170338', {'weight': 0.04878048780487809, 'label': 'default'}),
#  ('17476', '28456', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('17476', '33013', {'weight': 0.06666666666666665, 'label': 'default'}),
#  ('17476', '682666', {'weight': 0.1470588235294118, 'label': 'default'}),
#  ('17476', '892139', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('206259', '28487', {'weight': 0.08695652173913049, 'label': 'default'}),
#  ('206259', '28542', {'weight': 0.05128205128205132, 'label': 'default'}),
#  ('28202', '6163', {'weight': 0.13793103448275867, 'label': 'default'}),
#  ('28202', '6213', {'weight': 0.02941176470588236, 'label': 'default'}),
#  ('28202', '25791', {'weight': 0.1071428571428571, 'label': 'default'}),
#  ('28202', '1114629', {'weight': 0.09375, 'label': 'default'}),
#  ('28202', '1128267', {'weight': 0.10344827586206895, 'label': 'default'}),
#  ('28202', '325497', {'weight': 0.0, 'label': 'default'}),
#  ('28278', '910', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('28278', '4584', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('28278', '6213', {'weight': 0.03703703703703709, 'label': 'default'}),
#  ('28278', '6214', {'weight': 0.1578947368421053, 'label': 'default'}),
#  ('28278', '1107312', {'weight': 0.0, 'label': 'default'}),
#  ('32872', '17201', {'weight': 0.15000000000000002, 'label': 'default'}),
#  ('32872', '17208', {'weight': 0.15384615384615385, 'label': 'default'}),
#  ('33013', '18777', {'weight': 0.033333333333333326, 'label': 'default'}),
#  ('6214', '4584', {'weight': 0.05555555555555558, 'label': 'default'}),
#  ('6214', '6151', {'weight': 0.09375, 'label': 'default'}),
#  ('6214', '6213', {'weight': 0.1428571428571429, 'label': 'default'}),
#  ('6214', '1105764', {'weight': 0.07499999999999996, 'label': 'default'}),
#  ('6214', '1115886', {'weight': 0.05405405405405406, 'label': 'default'}),
#  ('6214', '1130600', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('6214', '1152740', {'weight': 0.04347826086956519, 'label': 'default'}),
#  ('6214', '13960', {'weight': 0.11764705882352944, 'label': 'default'}),
#  ('6214', '188471', {'weight': 0.11111111111111116, 'label': 'default'}),
#  ('6214', '27631', {'weight': 0.12121212121212122, 'label': 'default'}),
#  ('6214', '28447', {'weight': 0.14814814814814814, 'label': 'default'}),
#  ('6214', '345340', {'weight': 0.08571428571428574, 'label': 'default'}),
#  ('6214', '399339', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('6214', '6184', {'weight': 0.08333333333333337, 'label': 'default'}),
#  ('6214', '6215', {'weight': 0.2666666666666667, 'label': 'default'}),
#  ('6214', '6224', {'weight': 0.11428571428571432, 'label': 'default'}),
#  ('6214', '628500', {'weight': 0.12121212121212122, 'label': 'default'}),
#  ('6214', '6378', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('6214', '93320', {'weight': 0.045454545454545414, 'label': 'default'}),
#  ('6214', '95589', {'weight': 0.18181818181818177, 'label': 'default'}),
#  ('6214', '97892', {'weight': 0.02941176470588236, 'label': 'default'}),
#  ('75674', '27623', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('75674', '1109957', {'weight': 0.21212121212121215, 'label': 'default'}),
#  ('75674', '686015', {'weight': 0.040000000000000036, 'label': 'default'}),
#  ('20526', '6169', {'weight': 0.10526315789473684, 'label': 'default'}),
#  ('20526', '6213', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('20526', '1118092', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('13960', '1481', {'weight': 0.02564102564102566, 'label': 'default'}),
#  ('13960', '6213', {'weight': 0.04761904761904767, 'label': 'default'}),
#  ('13960', '13966', {'weight': 0.11904761904761907, 'label': 'default'}),
#  ('345340', '6224', {'weight': 0.10256410256410253, 'label': 'default'}),
#  ('345340', '18777', {'weight': 0.038461538461538436, 'label': 'default'}),
#  ('345340', '116790', {'weight': 0.0, 'label': 'default'}),
#  ('288', '1118092', {'weight': 0.13888888888888884, 'label': 'default'}),
#  ('288', '36167', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('288', '40151', {'weight': 0.125, 'label': 'default'}),
#  ('1118092', '28254', {'weight': 0.07894736842105265, 'label': 'default'}),
#  ('36167', '4584', {'weight': 0.07692307692307687, 'label': 'default'}),
#  ('36167', '20528', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('36167', '70520', {'weight': 0.1282051282051282, 'label': 'default'}),
#  ('424', '1135125', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('424', '218666', {'weight': 0.1333333333333333, 'label': 'default'}),
#  ('424', '47684', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('424', '77758', {'weight': 0.02777777777777779, 'label': 'default'}),
#  ('424', '197452', {'weight': 0.02631578947368418, 'label': 'default'}),
#  ('1135125', '1272', {'weight': 0.0, 'label': 'default'}),
#  ('1135125', '27543', {'weight': 0.0, 'label': 'default'}),
#  ('47684', '47682', {'weight': 0.023255813953488413, 'label': 'default'}),
#  ('47684', '68115', {'weight': 0.12, 'label': 'default'}),
#  ('267003', '75121', {'weight': 0.0714285714285714, 'label': 'default'}),
#  ('463', '58454', {'weight': 0.052631578947368474, 'label': 'default'}),
#  ('58454', '144679', {'weight': 0.1351351351351351, 'label': 'default'}),
#  ('58454', '87417', {'weight': 0.050000000000000044, 'label': 'default'}),
#  ('504', '1102364', {'weight': 0.08823529411764708, 'label': 'default'}),
#  ('504', '1112650', {'weight': 0.0, 'label': 'default'}),
#  ('504', '506', {'weight': 0.046511627906976716, 'label': 'default'}),
#  ('504', '89416', {'weight': 0.1515151515151515, 'label': 'default'}),
#  ('1102364', '506', {'weight': 0.09999999999999998, 'label': 'default'}),
#  ('506', '1106546', {'weight': 0.09523809523809523, 'label': 'default'}),
#  ('506', '89416', {'weight': 0.09756097560975607, 'label': 'default'}),
#  ...]

# %%
rw = BiasedRandomWalk(StellarGraph(g_nx_wt))

weighted_walks = rw.run(nodes=list(g_nx.nodes()), # root nodes
               length=100,  # maximum length of a random walk
               n=10,        # number of random walks per root node 
               p=0.5,       # Defines (unormalised) probability, 1/p, of returning to source node
               q=2.0,        # Defines (unormalised) probability, 1/q, for moving away from source node
               weighted = True
              )
print("Number of random walks: {}".format(len(weighted_walks)))
# Out:
# Number of random walks: 24850

# %% [markdown]
# ### Representation Learning using Word2Vec
#
# We use the `Word2Vec`, [2], implementation in the free Python library `Gensim`, [3], to learn representations for each node in the graph.
#
# We set the dimensionality of the learned embedding vectors to 128 as in [1].

# %%
from gensim.models import Word2Vec

model = Word2Vec(weighted_walks, size=128, window=5, min_count=0, sg=1, workers=2, iter=1)

# %%
# The embedding vectors can be retrieved from model.wv using the node ID as key.
model.wv['19231'].shape
# Out:
# (128,)

# %% [markdown]
# ### Visualise Node Embeddings
#
# We retrieve the `Word2Vec` node embeddings that are 128-dimensional vectors and then we project them down to 2 dimensions using the [t-SNE](http://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html) algorithm.

# %%
# Retrieve node embeddings and corresponding subjects
node_ids = model.wv.index2word  # list of node IDs
node_embeddings = model.wv.vectors  # numpy.ndarray of size number of nodes times embeddings dimensionality
node_targets = [ g_nx_wt.node[node_id]['subject'] for node_id in node_ids]

# %%
# Apply t-SNE transformation on node embeddings
tsne = TSNE(n_components=2)
node_embeddings_2d = tsne.fit_transform(node_embeddings)

# %%
# draw the points
alpha = 0.7
label_map = { l: i for i, l in enumerate(np.unique(node_targets))}
node_colours = [ label_map[target] for target in node_targets]

plt.figure(figsize=(20,16))
plt.scatter(node_embeddings_2d[:,0], 
            node_embeddings_2d[:,1], 
            c=node_colours, cmap = "jet", alpha = 0.7)

# %% [markdown]
# ### Downstream task
#
# The node embeddings calculated using `Word2Vec` can be used as feature vectors in a downstream task such as node attribute inference.
#
# In this example, we will use the `Node2Vec` node embeddings to train a classifier to predict the subject of a paper in Cora.

# %%
# X will hold the 128-dimensional input features
X = node_embeddings  
# y holds the corresponding target values
y = np.array(node_targets)

# %% [markdown]
# ### Data Splitting
#
# We split the data into train and test sets.
#
# We use 75% of the data for training and the remaining 25% for testing as a hold out test set.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, test_size=None)

# %%
print("Array shapes:\n X_train = {}\n y_train = {}\n X_test = {}\n y_test = {}".format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# Array shapes:
#  X_train = (1863, 128)
#  y_train = (1863,)
#  X_test = (622, 128)
#  y_test = (622,)

# %% [markdown]
# ### Classifier Training
#
# We train a Logistic Regression classifier on the training data.

# %%
clf = LogisticRegressionCV( Cs=10, 
                            cv=10, 
                            scoring="accuracy",
                            verbose=False,
                            multi_class='ovr')
clf.fit(X_train, y_train)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=10, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#            refit=True, scoring='accuracy', solver='lbfgs', tol=0.0001,
#            verbose=False)

# %% [markdown]
# Predict the hold out test set.

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# Calculate the accuracy of the classifier on the test set.

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8344051446945338
